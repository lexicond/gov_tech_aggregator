# %%
# !pip install PyYAML python-dotenv

# %%
import requests
import yaml
import os
from dotenv import load_dotenv

def fetch_gov_github_accounts(url):
    response = requests.get(url)
    if response.status_code == 200:
        return yaml.safe_load(response.text)
    else:
        return None

def fetch_repository_details(username, token):
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    repos_response = requests.get(repos_url, headers=headers)
    
    if repos_response.status_code == 200:
        repos_data = repos_response.json()
        full_repo_details = []
        
        for repo in repos_data:
            repo_details = {
                'name': repo['name'],
                'description': repo['description'] or "No description",
                'stars': repo['stargazers_count'],
                'forks': repo['forks'],
                'language': repo['language'] or "None specified"
            }
            # Fetch the README file
            readme_url = f"https://api.github.com/repos/{username}/{repo['name']}/readme"
            readme_response = requests.get(readme_url, headers=headers)
            if readme_response.status_code == 200:
                readme_data = readme_response.json()
                readme_content = requests.get(readme_data['download_url']).text
                repo_details['readme'] = readme_content[:100]  # Truncate for brevity
            else:
                repo_details['readme'] = "README not available"
            
            full_repo_details.append(repo_details)
        
        return full_repo_details
    else:
        return None

def save_to_markdown(repos, filename):
    with open(filename, 'w') as f:
        f.write('| Repository Name | Description | Stars | Language | README |\n')
        f.write('|-----------------|-------------|-------|----------|--------|\n')
        for repo in repos:
            f.write(f"| {repo['name']} | {repo['description']} | {repo['stars']} | {repo['language']} | {repo['readme'][:50]}... |\n")


# Load environment variables from .env file
load_dotenv('.env')

# Load environment variables from .env file
load_dotenv('.env')

# Access environment variables
github_token = os.getenv('GITHUB_TOKEN')
if not github_token:
    raise ValueError("GITHUB_TOKEN not found in environment variables. Please check your .env file.")


# Main execution
url = "https://raw.githubusercontent.com/github/government.github.com/gh-pages/_data/governments.yml"
accounts = fetch_gov_github_accounts(url)

accounts
# Out:
# {'Argentina': ['argob',
#   'cifasis',
#   'gcba',
#   'inti-cmnb',
#   'municipalidad-de-vicente-lopez',
#   'municipioriogrande'],
#  'Australia': ['actesa',
#   'actgov',
#   'agnsw',
#   'AtlasOfLivingAustralia',
#   'ausdto',
#   'australianantarcticdatacentre',
#   'AustralianAntarcticDivision',
#   'berowrarfb',
#   'bom-radar',
#   'city-of-melbourne',
#   'commerce-wa-ols',
#   'consumerdataright',
#   'data61',
#   'datagovau',
#   'dbca-wa',
#   'dpc-sdp',
#   'dpipwe',
#   'dssgovaus',
#   'envris',
#   'Fire-and-Rescue-NSW',
#   'gccgisteam',
#   'GeoscienceAustralia',
#   'govau',
#   'govcms',
#   'gs-dawr',
#   'healthgovau',
#   'Healthway',
#   'hiscom',
#   'innovationgovau',
#   'IPAustralia',
#   'Landgate',
#   'nla',
#   'NSW-eTendering',
#   'NSWPlanning',
#   'pmcau',
#   'PublicRecordOfficeVictoria',
#   'qld-gov-au',
#   'srnsw',
#   'SunshineCoastCouncil',
#   'treasury-aus',
#   'victoriangovernment',
#   'wagov',
#   'wamuseum'],
#  'Austria': ['datagvat'],
#  'Belgium': ['belgianpolice',
#   'CIRB',
#   'Fedict',
#   'inbo',
#   'NationalBankBelgium',
#   'onroerenderfgoed',
#   'StadGent'],
#  'Bolivia': ['adsib', 'geobolivia'],
#  'Brazil': ['bacendeinf',
#   'camaradosdeputadosoficial',
#   'cenima-ibama',
#   'cislgov',
#   'culturagovbr',
#   'dadosgovbr',
#   'dataprev',
#   'EscolaDeSaudePublica',
#   'fablablivresp',
#   'fateczonaleste',
#   'gabinetedigital',
#   'govbr',
#   'GovBrasil',
#   'imagov',
#   'InstitutoBenjaminConstant',
#   'interlegis',
#   'justicagovbr',
#   'labhackercd',
#   'lexml',
#   'MP-ES',
#   'MP-RJ',
#   'pensandoodireito',
#   'plonegovbr',
#   'pr-snas',
#   'prefeitura-rio',
#   'prefeiturasp',
#   'PROCERGS',
#   'prodest',
#   'secom-tocantins',
#   'secultce',
#   'sepinf-inc',
#   'servicosgovbr',
#   'smcti',
#   'tcers',
#   'tisorocaba',
#   'tre-pa',
#   'wpgovbr'],
#  'Bulgaria': ['govbg', 'governmentbg'],
#  'Cambodia': ['e-Government-Cambodia'],
#  'Canada': ['AAFC-BICoE',
#   'abgov',
#   'asc-csa',
#   'bac-lac',
#   'BCGov',
#   'canada-ca',
#   'cds-snc',
#   'CityofEdmonton',
#   'cityofgreatersudbury',
#   'cityofottawa',
#   'CityOfSarnia',
#   'cityofsurrey',
#   'CityofToronto',
#   'cityssm',
#   'cngo',
#   'csbp-cpse',
#   'cse-cst',
#   'CSPS-EFPC-DAAN',
#   'CybercentreCanada',
#   'DTS-STN',
#   'ECCC-MSC',
#   'eodms-sgdot',
#   'esdc-devx',
#   'esdc-edsc',
#   'ExchangeBC',
#   'fgpv-vpgf',
#   'gc-proto',
#   'gcperformance',
#   'GCTC-NTGC',
#   'gctools-outilsgc',
#   'GeoCanViz',
#   'GNWT',
#   'GovAlta',
#   'infra-geo-ouverte',
#   'justicecanada',
#   'LMID-DIMT',
#   'MC-MBO-WebPublishingTeam',
#   'MetPX',
#   'nrc-cnrc',
#   'NRCan',
#   'nsgov',
#   'ongov',
#   'open-data',
#   'phac-aspc',
#   'phac-nml',
#   'PHACDataHub',
#   'pspc-spac',
#   'PSPC-SPAC-buyandsell',
#   'RAMP-PCAR',
#   'RDOQ',
#   'ServiceCanada',
#   'StatCan',
#   'TBS-EACPD',
#   'tc-ca',
#   'veteransaffairscanada',
#   'VilledeMontreal',
#   'wet-boew',
#   'ytgov'],
#  'Chile': ['e-gob'],
#  'China': ['CPPUer', 'PPSUCers'],
#  'Colombia': ['AltaConsejeriaTIC', 'evaluon', 'idu-bogota'],
#  'Czech Republic': ['MinistryOfJusticeCZ', 'NLCR', 'opendata-mvcr'],
#  'Denmark': ['kb-dk',
#   'Kortforsyningen',
#   'NationalMuseumofDenmark',
#   'Notalib',
#   'skat',
#   'ssi-dk',
#   'StatensMuseumforKunst'],
#  'Ecuador': ['inamhi', 'innovacionsnap', 'senescyt'],
#  'Egypt': ['informationtechnologyinstitute'],
#  'Estonia': ['e-gov', 'kinnisvara', 'MKM-ITAO', 'open-eid', 'opendata-ee'],
#  'Ethiopia': ['ethiopian'],
#  'European Union': ['digital-services-act',
#   'ec-europa',
#   'eea',
#   'eu-digital-green-certificates',
#   'eu-digital-identity-wallet',
#   'europarl',
#   'european-central-bank',
#   'europeana',
#   'openeuropa'],
#  'Finland': ['6Aika',
#   'City-of-Helsinki',
#   'City-of-Turku',
#   'CSC-IT-Center-for-Science',
#   'espoon-voltti',
#   'finnishtransportagency',
#   'Helsingin-kaupungin-tietokeskus',
#   'helsinki-city-library',
#   'HSLdevcom',
#   'Lounaispaikka',
#   'lukefi',
#   'NatLibFi',
#   'nlsfi',
#   'opetushallitus',
#   'sykefi',
#   'vrk-kpa'],
#  'France': ['afimb',
#   'AlsaceDigitale',
#   'AmbaNum',
#   'ansforge',
#   'ANSSI-FR',
#   'ApieFrance',
#   'atih',
#   'betagouv',
#   'BRGM',
#   'cea-hpc',
#   'cea-leti',
#   'cea-list',
#   'cea-sec',
#   'clipos',
#   'clipos-archive',
#   'communaute-cimi',
#   'culturecommunication',
#   'cw-leia',
#   'DGFiP',
#   'diplomatiegouvfr',
#   'disic',
#   'DREAL-NA',
#   'entrepreneur-interet-general',
#   'erasme',
#   'etalab',
#   'Inist-CNRS',
#   'InseeFr',
#   'lutece-secteur-public',
#   'MINAGRI-INITIAL',
#   'MinistereSupRecherche',
#   'MTES-MCT',
#   'nanterre',
#   'nantesmetropole',
#   'opencti-platform',
#   'PnCevennes',
#   'PnEcrins',
#   'PnX-SI',
#   'polewebmaedi',
#   'ProgrammeVitam',
#   'region-bretagne',
#   'sgmap-agd',
#   'SocialGouv',
#   'SocieteNumerique',
#   'strasbourg',
#   'wookey-project'],
#  'French Polynesia': ['sipf'],
#  'Germany': ['Basisvisualisierung',
#   'BSI-Bund',
#   'buehl',
#   'CERT-Bund',
#   'corona-warn-app',
#   'dbmdz',
#   'Digitaler-Impfnachweis',
#   'digitalservicebund',
#   'gbv',
#   'GovDataOfficial',
#   'hbz',
#   'isyfact',
#   'it-at-m',
#   'kdn-nrw',
#   'kreis-viersen',
#   'lobid',
#   'Oberverwaltungsgericht-Rheinland-Pfalz',
#   'OpenBfS',
#   'OpenNRW',
#   'regional-digital',
#   'robert-koch-institut',
#   'rostock',
#   'stadt-bielefeld',
#   'stadt-karlsruhe',
#   'StadtBruchsal',
#   'stadtulm'],
#  'Guatemala': ['minfingt'],
#  'Hong Kong': ['datagovhk'],
#  'Hungary': ['fphgov'],
#  'India': ['DataPortalIndia', 'ISRO', 'itschool', 'npci'],
#  'Indonesia': ['bolsel', 'jabardigitalservice', 'pemkab-rembang'],
#  'International': ['EL-BID', 'IATI', 'ogpl'],
#  'Ireland': ['HSEIreland', 'ogcio'],
#  'Isle of Man': ['Isle-Of-Man-Government'],
#  'Israel': ['CIOIL', 'Digital-Israel', 'MohGovIL', 'MostIL'],
#  'Italy': ['AgID',
#   'ComuneBologna',
#   'Formez',
#   'pcm-dpc',
#   'PloneGov-IT',
#   'RegioneER',
#   'TeamDigitale'],
#  'Japan': ['city-of-kobe',
#   'codefornamie',
#   'gsi-cyberjapan',
#   'nhohq',
#   'nims-dpfc'],
#  'Jersey': ['statesofjersey'],
#  'Kosovo': ['map-ashi'],
#  'Latvia': ['CSBLatvia'],
#  'Lithuania': ['AplinkosMinisterija',
#   'govlt',
#   'ivpk',
#   'KeliaukLietuvoje',
#   'Nacionaline-sporto-agentura',
#   'viesujupirkimutarnyba',
#   'vilnius',
#   'VMVT-DevHub'],
#  'Luxemburg': ['circl', 'Geoportail-Luxembourg', 'natliblux', 'opendatalu'],
#  'Malaysia': ['pmo2'],
#  'Mauritius': ['MUnosecc'],
#  'Mexico': ['CSB-IG',
#   'DDT-INMEGEN',
#   'IDEA-GTO',
#   'inmegen',
#   'LabLeon',
#   'mxabierto',
#   'PJECZ',
#   'profeco',
#   'redoaxacadetodos'],
#  'Netherlands': ['Amsterdam',
#   'dataoverheid',
#   'GemeenteAlmelo',
#   'GemeenteEde',
#   'Geonovum',
#   'Haarlem',
#   'IenS-Velsen',
#   'KBNLresearch',
#   'Logius-standaarden',
#   'MinBZK',
#   'MinELenI',
#   'minvws',
#   'Pleio',
#   'politie',
#   'provinciegroningen',
#   'provincieNH',
#   'StichtingHergebruikOverheid',
#   'TweedeKamer',
#   'zaanstad'],
#  'New Zealand': ['CanterburyRegionalCouncil',
#   'data-govt-nz',
#   'DigitalNZ',
#   'docgovtnz',
#   'ElectricityAuthority',
#   'GOVTNZ',
#   'linz',
#   'localgovernment',
#   'MfE-NZ',
#   'nz-social-investment-agency',
#   'opcnz',
#   'te-papa'],
#  'Norway': ['altinn',
#   'bergenkommune',
#   'brreg',
#   'danskernesdigitalebibliotek',
#   'difi',
#   'digibib',
#   'DirektoratetForByggkvalitet',
#   'dsb-norge',
#   'dss-web',
#   'kartverket',
#   'knreise',
#   'KRD-KOMM-VL',
#   'metno',
#   'miljodir',
#   'nasjonalmuseet',
#   'navikt',
#   'nlbdev',
#   'Nordland-fylkeskommune',
#   'politiet',
#   'Riksrevisjonen',
#   'Rogaland',
#   'rutebanken',
#   'ruterno',
#   'Skatteetaten',
#   'StatensPensjonskasse',
#   'statisticsnorway',
#   'telemark',
#   'telemark-arkiv',
#   'Tolletaten',
#   'uninett',
#   'vegvesen'],
#  'Panama': ['IFARHU', 'miambiente'],
#  'Paraguay': ['mecpy', 'SENATICS'],
#  'Peru': ['imarpe'],
#  'Philippines': ['corcueraromblon', 'govph', 'igovphil', 'Laoag-City'],
#  'Poland': ['coi-gov-pl', 'Ministerstwo-Cyfryzacji', 'nationalmuseum'],
#  'Portugal': ['amagovpt'],
#  'Republic of Korea': ['molit-korea'],
#  'Romania': ['govro', 'MinistryOfLabor'],
#  'Russia': ['cikrf', 'ghalghai', 'kznru', 'moscow-technologies'],
#  'Saudi Arabia': ['SAS-NCDC'],
#  'Singapore': ['dsaidgovsg', 'govtechsg', 'moexmen', 'opengovsg'],
#  'Slovakia': ['slovak-egov'],
#  'South Africa': ['eddZA'],
#  'Spain': ['AjMalgrat',
#   'AjuntamentdeBarcelona',
#   'AjuntamentdeCalafell',
#   'AjuntamentdeCastello',
#   'AjuntamentDeGava',
#   'AjuntamentDeMataro',
#   'AjuntamentdeReus',
#   'AjuntamentdeSabadell',
#   'AjuntamentdeSantCugat',
#   'AjuntamentdeTerrassa',
#   'AyuntamientoMadrid',
#   'ctt-gob-es',
#   'ErabakiPamplona',
#   'gencat',
#   'GobiernoLaRioja',
#   'HospitaletDeLlobregat',
#   'icane',
#   'lliurex',
#   'projectestac',
#   'vilanovailageltru'],
#  'Sweden': ['Alingsas-Kommun',
#   'arbetsformedlingen',
#   'domstol',
#   'dotse',
#   'elegnamnden',
#   'Forsakringskassan',
#   'gbif-sweden',
#   'Helsingborg',
#   'helsingborg-stad',
#   'ISOF-ITD',
#   'jobtechswe',
#   'kungbib',
#   'Lantmateriet',
#   'libris',
#   'lldd',
#   'lshSWE',
#   'malmostad',
#   'mtmse',
#   'NationalmuseumSWE',
#   'NordicMuseum',
#   'regionhalland',
#   'regionostergotland',
#   'riksantikvarieambetet',
#   'riksarkivet',
#   'rinfo',
#   'sambruk',
#   'SciLifeLab',
#   'SICS',
#   'skolverket',
#   'smhi',
#   'SodertornHB',
#   'statens-maritima-museer',
#   'statisticssweden',
#   'Sundsvallskommun',
#   'Sunet',
#   'sverigesradio',
#   'SVT',
#   'SwedenConnect',
#   'swedish-council-for-higher-education',
#   'swedishpensionsagency',
#   'The-Municipality-of-Staffanstorp',
#   'umea-kommun',
#   'Vastra-Gotalandsregionen',
#   'vasttrafik'],
#  'Switzerland': ['admin-ch',
#   'alv-ch',
#   'BFS-SHS-MSAS',
#   'dsi-vd',
#   'FNSKtZH',
#   'geoadmin',
#   'gisktzh',
#   'kanton-aargau',
#   'kanton-bern',
#   'metas-ch',
#   'ogdch',
#   'ogdtg',
#   'opendatabs',
#   'opendatazurich',
#   'openZH',
#   'SFOE',
#   'sitn',
#   'statistikstadtzuerich',
#   'statistikZH',
#   'VerkehrsbetriebeZuerich'],
#  'Taiwan': ['moda-gov-tw', 'pdis', 'taipei-doit', 'taipeicity'],
#  'Thailand': ['DGA-Thailand'],
#  'U.K. Central': ['111online',
#   'acteng',
#   'alphagov',
#   'BEACmodel',
#   'britishlibrary',
#   'cabinetoffice',
#   'CDPS-Wales',
#   'CJSCommonPlatform',
#   'co-cddo',
#   'communitiesuk',
#   'companieshouse',
#   'CPS-Innovation',
#   'datagovuk',
#   'datasciencecampus',
#   'decc',
#   'defra',
#   'DFE-Digital',
#   'dfid',
#   'digital-preservation',
#   'directgov-innovate',
#   'dstl',
#   'dvla',
#   'dvsa',
#   'dwp',
#   'GCHQ',
#   'gds-dead',
#   'gds-operations',
#   'govuk-one-login',
#   'guidance-guarantee-programme',
#   'hmcts',
#   'HMPO',
#   'hmrc',
#   'HO-CTO',
#   'houseofcommonslibrary',
#   'i-dot-ai',
#   'informatics-lab',
#   'insolvencyservice',
#   'intellectual-property-office',
#   'IQuOD',
#   'jncc',
#   'JNCC-UK',
#   'jules-lsm',
#   'LandRegistry',
#   'landregistry-ops',
#   'lgss',
#   'LocalGovDigital',
#   'MarineScotlandScience',
#   'MetOffice',
#   'MetOfficeSpaceApps',
#   'metomi',
#   'MHRA',
#   'ministryofjustice',
#   'moj-analytical-services',
#   'naouk',
#   'nationalarchives',
#   'NationalCrimeAgency',
#   'NationalLibraryOfScotland',
#   'nhsconnect',
#   'nhsdigital',
#   'nhsengland',
#   'nhsuk',
#   'NHSX',
#   'nice-digital',
#   'nihp-public',
#   'OfqualGovUK',
#   'ONSdigital',
#   'openregister',
#   'OrdnanceSurvey',
#   'osgeouk',
#   'scottishgovernment',
#   'SkillsFundingAgency',
#   'tanc-ahrc',
#   'ukforeignoffice',
#   'ukgovdatascience',
#   'UKGovernmentBEIS',
#   'UKHomeOffice',
#   'UKHomeOfficeForms',
#   'UKLocation',
#   'ukncsc',
#   'ukparliament',
#   'uktrade',
#   'ukwa'],
#  'U.K. Councils': ['BathnesDevelopment',
#   'BracknellForestCouncil',
#   'brighton-hove-gov-uk',
#   'BristolCityCouncil',
#   'CamdenCouncil',
#   'cityofyork',
#   'devoncc',
#   'DevonCountyCouncil',
#   'Dorset-Council-UK',
#   'DundeeCityCouncil',
#   'east-sussex-county-council',
#   'edinburghcouncil',
#   'essexcountycouncil',
#   'gmfrs',
#   'GuildfordBC',
#   'HfdsCouncil',
#   'kentcc',
#   'LambethCouncil',
#   'lichfield-district-council',
#   'LondonBoroughSutton',
#   'LutonCouncil',
#   'openglasgow',
#   'RoyalBoroughKingston',
#   'smbc-digital',
#   'surreydigitalservices',
#   'thehighlandcouncil',
#   'TraffordCouncil',
#   'warwickshire',
#   'wealden',
#   'west-berkshire-council',
#   'wmfs'],
#  'U.S. City': ['austincodeit',
#   'Baltimore-City-EGIS',
#   'berkeleypubliclibrary',
#   'BostonRedevelop',
#   'cambridgedata',
#   'cambridgegis',
#   'chicago',
#   'city-of-bellingham',
#   'city-of-bloomington',
#   'cityofasheville',
#   'CityOfAuburnAL',
#   'cityofaustin',
#   'cityofboise',
#   'CityOfBoston',
#   'cityofboulder',
#   'cityofburlington',
#   'cityofchattanooga',
#   'CityOfDetroit',
#   'CityOfLosAngeles',
#   'cityofnewyork',
#   'CityOfPhiladelphia',
#   'CityofPittsburgh',
#   'cityofportland',
#   'CityofReno',
#   'CityofSanFrancisco',
#   'CityofSantaMonica',
#   'cityofsomerville',
#   'cityofvernonia',
#   'CityOfVirginiaBeach',
#   'cityofwestsacramento',
#   'CityofYakima',
#   'cno-opa',
#   'CORaleigh',
#   'CUMTD',
#   'DCCouncil',
#   'DCgov',
#   'DenverDev',
#   'digitalinclusion',
#   'egovpdx',
#   'Honolulu',
#   'kcmo',
#   'lfucg',
#   'longbeachinnovationteam',
#   'LouisvilleMetro',
#   'louisvillemetro-innovation',
#   'mnhrc',
#   'mnylc',
#   'moda-nyc',
#   'monum',
#   'NewYorkCityCouncil',
#   'NYCComptroller',
#   'nycdot',
#   'NYCPlanning',
#   'onc-healthit',
#   'OpenGovDC',
#   'p2g',
#   'pdxgis',
#   'PierceCountyWA',
#   'ProBonoDC',
#   'ridertd',
#   'SantaClarita',
#   'sfbart',
#   'SiloamSprings',
#   'southbendin',
#   'TownOfBrookline',
#   'tucsonaz'],
#  'U.S. County': ['anoka-script-team',
#   'ArlingtonCounty',
#   'baltimorecounty',
#   'BayAreaMetro',
#   'bouldercounty',
#   'Canyon-County',
#   'CarverCounty',
#   'donaanacounty',
#   'fairfieldcountyit',
#   'fpdcc',
#   'HarrisCountyFOA',
#   'HennepinCountyPublicDefender',
#   'LACMTA',
#   'MCLD',
#   'pottcountyit',
#   'saccounty',
#   'sfcta',
#   'slugis'],
#  'U.S. Federal': ['18f',
#   'adl-aicc',
#   'adlnet',
#   'afrl',
#   'arcticlcc',
#   'BBGInnovate',
#   'bfelob',
#   'blue-button',
#   'businessusa',
#   'CA-CST-Library',
#   'CA-CST-SII',
#   'ccmc',
#   'CDCgov',
#   'cfpb',
#   'cigiegov',
#   'cisagov',
#   'cloud-gov',
#   'cmsgov',
#   'Code-dot-mil',
#   'commercedataservice',
#   'commercegov',
#   'demand-driven-open-data',
#   'department-of-veterans-affairs',
#   'dhs-gov',
#   'didsr',
#   'digital-analytics-program',
#   'dodcio',
#   'doecode',
#   'doi-open-data',
#   'EEOC',
#   'energyapps',
#   'erdc',
#   'eregs',
#   'FAA-Aviation-Data-Portal',
#   'fcc',
#   'fda',
#   'fecgov',
#   'Federal-Aviation-Administration',
#   'federal-courts-software-factory',
#   'federaltradecommission',
#   'fedramp',
#   'fedspendingtransparency',
#   'fema',
#   'firelab',
#   'globegit',
#   'gopleader',
#   'government-services',
#   'GrainGenes',
#   'gsa',
#   'gsa-oes',
#   'gsa-tts',
#   'hhs',
#   'HHS-AHRQ',
#   'HHSDigitalMediaAPIPlatform',
#   'HHSIDEAlab',
#   'historyatstate',
#   'IIP-Design',
#   'IMDProjects',
#   'imls',
#   'informaticslab',
#   'Innovation-Toolkit',
#   'internationaltradeadministration',
#   'ioos',
#   'IRSgov',
#   'keplergo',
#   'libraryofcongress',
#   'M-O-S-E-S',
#   'mcc-gov',
#   'missioncommand',
#   'nasa',
#   'nasa-develop',
#   'nasa-gibs',
#   'NASA-rdt',
#   'nasa-tournament-lab',
#   'nasaworldwind',
#   'NationalGuard',
#   'nationalparkservice',
#   'navadmc',
#   'NCI-Agency',
#   'NCRN',
#   'NeoGeographyToolkit',
#   'nesii',
#   'ngds',
#   'nhanes',
#   'nidcd',
#   'NIEM',
#   'NMB-Dev',
#   'NMML',
#   'NOAA-EPIC',
#   'noaa-gfdl',
#   'NOAA-ORR-ERD',
#   'noaa-pmel',
#   'ntia',
#   'NUWCDIVNPT',
#   'ombegov',
#   'Open-Sat',
#   'opengovplatform',
#   'ozoneplatform',
#   'peacecorps',
#   'petsc',
#   'presidential-innovation-fellows',
#   'project-open-data',
#   'radiofreeasia',
#   'redhawksdr',
#   'regulationsgov',
#   'sbstusa',
#   'SelectUSA',
#   'SERVIR',
#   'SSAgov',
#   'state-hiu',
#   'sunpy',
#   'us-bea',
#   'US-CBP',
#   'US-Department-of-the-Treasury',
#   'usagov',
#   'usaid',
#   'usasearch',
#   'usbr',
#   'uscensusbureau',
#   'uscis',
#   'usda',
#   'usda-ars-agil',
#   'usda-ars-gbru',
#   'usda-ars-ltar',
#   'usda-ars-nwrc',
#   'usda-ars-wmsru',
#   'USDA-ERS',
#   'USDA-FSA',
#   'usda-nifa-b-team',
#   'usda-vs',
#   'usdaForestService',
#   'usdepartmentoflabor',
#   'usdoj',
#   'usdot-fhwa-stol',
#   'usdot-jpo-ode',
#   'usds',
#   'useda',
#   'usepa',
#   'USFWS',
#   'usg-scope',
#   'USGCRP',
#   'usgpo',
#   'usgs',
#   'USGS-Astrogeology',
#   'usgs-cmg',
#   'usgs-eros',
#   'USGS-OWI',
#   'USGS-R',
#   'USGS-WiM',
#   'usnationalarchives',
#   'usopm',
#   'USPS',
#   'USPTO',
#   'USSBA',
#   'usstatedept',
#   'ustaxcourt',
#   'uswds',
#   'VHAINNOVATIONS',
#   'virtual-world-framework',
#   'visionworkbench',
#   'weather-gov',
#   'WFMRDA',
#   'whitehouse',
#   'XDgov'],
#  'U.S. Local Law Enforcement': ['SanDiegoCountySheriff'],
#  'U.S. Military and Intelligence': ['afseo',
#   'CRREL',
#   'deptofdefense',
#   'dod-cyber-crime-center',
#   'erdc-itl',
#   'iadgov',
#   'info-sharing-environment',
#   'NationalSecurityAgency',
#   'ngageoint',
#   'nsacyber',
#   'project-interoperability',
#   'psns-imf',
#   'shareandprotect',
#   'SIMP',
#   'transcom',
#   'usarmyresearchlab',
#   'USNavalResearchLaboratory'],
#  'U.S. Special District': ['atlregional',
#   'AZMAG',
#   'baaqmd',
#   'cleveland-metroparks',
#   'CMAP-REPOS',
#   'commonwealth-of-puerto-rico',
#   'MAPC',
#   'Metropolitan-Council',
#   'portofsandiego',
#   'psrc'],
#  'U.S. States': ['agrc',
#   'akhealth',
#   'azgs',
#   'cagov',
#   'CAWaterBoardDataCenter',
#   'ccap',
#   'CentralValleyModeling',
#   'coloradodemography',
#   'CTOpenData',
#   'DCGovWeb',
#   'eHawaii',
#   'FGS-FloridaGeologicalSurvey',
#   'gaepdit',
#   'gocodecolorado',
#   'IDAHO-DOC-NCOMS',
#   'idahofishgame',
#   'judicialcouncilcalifornia',
#   'la-ots',
#   'LADCO',
#   'LibraryofVA',
#   'massgov',
#   'MESMD',
#   'MFWP-GIS',
#   'nebraskamap',
#   'nelegislature',
#   'NJOGIS',
#   'njstatelibrary',
#   'ny',
#   'nys-its',
#   'nysenate',
#   'oimt',
#   'okcareertech',
#   'oregonopendata',
#   'ORMetro',
#   'scgeology',
#   'SLNC-DIMP',
#   'State-of-Arizona',
#   'StateOfCalifornia',
#   'swibwi',
#   'tndidd',
#   'TNRIS',
#   'twdb',
#   'TxDOT',
#   'UtahForestryFireStateLands',
#   'VDGIF',
#   'Virginia-Department-of-Health',
#   'Virginia-House-of-Delegates',
#   'vtrans',
#   'vtrans-rail',
#   'WA-Department-of-Agriculture',
#   'wsdot',
#   'WSDOT-GIS'],
#  'U.S. Tribal Nations': ['coquille-indian-tribe',
#   'MSBandofChoctawIndians',
#   'osage-nation'],
#  'Ukraine': ['openprocurement'],
#  'United Nations': ['GFDRR',
#   'OCHA-DAP',
#   'UN-ICC',
#   'UN-OCHA',
#   'uncefact',
#   'undp',
#   'unesco',
#   'UNGlobalPlatform',
#   'unicef',
#   'unido',
#   'UNStats',
#   'worldbank',
#   'WorldBank-Transport',
#   'WorldHealthOrganization'],
#  'Venezuela': ['CanaimaGNULinux', 'suscerte']}

# %%
import pandas as pd


all_repos = []
if accounts:
    for country, usernames in accounts.items():
        for username in usernames:
            repo_details = fetch_repository_details(username, github_token)
            if repo_details:
                all_repos.extend(repo_details)
                print(f"Data for {username} fetched and processed.")
            else:
                print(f"Failed to fetch data for {username}")

# Create DataFrame and save to Markdown
if all_repos:
    repos_df = pd.DataFrame(all_repos)
    markdown_file = "all_government_repositories.md"
    save_to_markdown(repos_df, markdown_file)
    print(f"All data saved to {markdown_file}")
    # Optionally save to CSV or another format
    repos_df.to_csv("all_government_repositories.csv", index=False)
    print("Data also saved as a CSV file.")
else:
    print("No repository data collected.")
# Out:
# Data for argob fetched and processed.
# Data for cifasis fetched and processed.
# Data for gcba fetched and processed.
# Data for inti-cmnb fetched and processed.
# Data for municipalidad-de-vicente-lopez fetched and processed.
# Data for municipioriogrande fetched and processed.
# Failed to fetch data for actesa
# Data for actgov fetched and processed.
# Data for agnsw fetched and processed.
# Data for AtlasOfLivingAustralia fetched and processed.
# Data for ausdto fetched and processed.
# Data for australianantarcticdatacentre fetched and processed.
# Data for AustralianAntarcticDivision fetched and processed.
# Data for berowrarfb fetched and processed.
# Data for bom-radar fetched and processed.
# Data for city-of-melbourne fetched and processed.
# Data for commerce-wa-ols fetched and processed.
# Data for consumerdataright fetched and processed.
# Data for data61 fetched and processed.
# Data for datagovau fetched and processed.
# Data for dbca-wa fetched and processed.
# Data for dpc-sdp fetched and processed.
# Data for dpipwe fetched and processed.
# Data for dssgovaus fetched and processed.
# Data for envris fetched and processed.
# Failed to fetch data for Fire-and-Rescue-NSW
# Data for gccgisteam fetched and processed.
# Data for GeoscienceAustralia fetched and processed.
# Data for govau fetched and processed.
# Data for govcms fetched and processed.
# Data for gs-dawr fetched and processed.
# Data for healthgovau fetched and processed.
# Failed to fetch data for Healthway
# Data for hiscom fetched and processed.
# Data for innovationgovau fetched and processed.
# Data for IPAustralia fetched and processed.
# Data for Landgate fetched and processed.
# Data for nla fetched and processed.
# Data for NSW-eTendering fetched and processed.
# Data for NSWPlanning fetched and processed.
# Data for pmcau fetched and processed.
# Data for PublicRecordOfficeVictoria fetched and processed.
# Data for qld-gov-au fetched and processed.
# Data for srnsw fetched and processed.
# Data for SunshineCoastCouncil fetched and processed.
# Failed to fetch data for treasury-aus
# Data for victoriangovernment fetched and processed.
# Data for wagov fetched and processed.
# Data for wamuseum fetched and processed.
# Data for datagvat fetched and processed.
# Data for belgianpolice fetched and processed.
# Data for CIRB fetched and processed.
# Data for Fedict fetched and processed.
# Data for inbo fetched and processed.
# Data for NationalBankBelgium fetched and processed.
# Data for onroerenderfgoed fetched and processed.
# Data for StadGent fetched and processed.
# Data for adsib fetched and processed.
# Data for geobolivia fetched and processed.
# Data for bacendeinf fetched and processed.
# Failed to fetch data for camaradosdeputadosoficial
# Data for cenima-ibama fetched and processed.
# Data for cislgov fetched and processed.
# Data for culturagovbr fetched and processed.
# Data for dadosgovbr fetched and processed.
# Data for dataprev fetched and processed.
# Failed to fetch data for EscolaDeSaudePublica
# Data for fablablivresp fetched and processed.
# Data for fateczonaleste fetched and processed.
# Data for gabinetedigital fetched and processed.
# Data for govbr fetched and processed.
# Data for GovBrasil fetched and processed.
# Data for imagov fetched and processed.
# Data for InstitutoBenjaminConstant fetched and processed.
# Data for interlegis fetched and processed.
# Data for justicagovbr fetched and processed.
# Data for labhackercd fetched and processed.
# Data for lexml fetched and processed.
# Data for MP-ES fetched and processed.
# Data for MP-RJ fetched and processed.
# Data for pensandoodireito fetched and processed.
# Data for plonegovbr fetched and processed.
# Data for pr-snas fetched and processed.
# Data for prefeitura-rio fetched and processed.
# Data for prefeiturasp fetched and processed.
# Data for PROCERGS fetched and processed.
# Data for prodest fetched and processed.
# Data for secom-tocantins fetched and processed.
# Data for secultce fetched and processed.
# Data for sepinf-inc fetched and processed.
# Data for servicosgovbr fetched and processed.
# Data for smcti fetched and processed.
# Failed to fetch data for tcers
# Data for tisorocaba fetched and processed.
# Data for tre-pa fetched and processed.
# Data for wpgovbr fetched and processed.
# Data for govbg fetched and processed.
# Data for governmentbg fetched and processed.
# Data for e-Government-Cambodia fetched and processed.
# Data for AAFC-BICoE fetched and processed.
# Data for abgov fetched and processed.
# Data for asc-csa fetched and processed.
# Data for bac-lac fetched and processed.
# Data for BCGov fetched and processed.
# Data for canada-ca fetched and processed.
# Data for cds-snc fetched and processed.
# Data for CityofEdmonton fetched and processed.
# Data for cityofgreatersudbury fetched and processed.
# Data for cityofottawa fetched and processed.
# Data for CityOfSarnia fetched and processed.
# Data for cityofsurrey fetched and processed.
# Data for CityofToronto fetched and processed.
# Data for cityssm fetched and processed.
# Data for cngo fetched and processed.
# Data for csbp-cpse fetched and processed.
# Data for cse-cst fetched and processed.
# Data for CSPS-EFPC-DAAN fetched and processed.
# Data for CybercentreCanada fetched and processed.
# Data for DTS-STN fetched and processed.
# Data for ECCC-MSC fetched and processed.
# Data for eodms-sgdot fetched and processed.
# Data for esdc-devx fetched and processed.
# Data for esdc-edsc fetched and processed.
# Data for ExchangeBC fetched and processed.
# Data for fgpv-vpgf fetched and processed.
# Data for gc-proto fetched and processed.
# Data for gcperformance fetched and processed.
# Data for GCTC-NTGC fetched and processed.
# Data for gctools-outilsgc fetched and processed.
# Data for GeoCanViz fetched and processed.
# Data for GNWT fetched and processed.
# Data for GovAlta fetched and processed.
# Data for infra-geo-ouverte fetched and processed.
# Data for justicecanada fetched and processed.
# Data for LMID-DIMT fetched and processed.
# Data for MC-MBO-WebPublishingTeam fetched and processed.
# Data for MetPX fetched and processed.
# Data for nrc-cnrc fetched and processed.
# Data for NRCan fetched and processed.
# Data for nsgov fetched and processed.
# Data for ongov fetched and processed.
# Data for open-data fetched and processed.
# Data for phac-aspc fetched and processed.
# Data for phac-nml fetched and processed.
# Data for PHACDataHub fetched and processed.
# Data for pspc-spac fetched and processed.
# Data for PSPC-SPAC-buyandsell fetched and processed.
# Data for RAMP-PCAR fetched and processed.
# Data for RDOQ fetched and processed.
# Data for ServiceCanada fetched and processed.
# Data for StatCan fetched and processed.
# Data for TBS-EACPD fetched and processed.
# Data for tc-ca fetched and processed.
# Data for veteransaffairscanada fetched and processed.
# Data for VilledeMontreal fetched and processed.
# Data for wet-boew fetched and processed.
# Data for ytgov fetched and processed.
# Failed to fetch data for e-gob
# Data for CPPUer fetched and processed.
# Data for PPSUCers fetched and processed.
# Data for AltaConsejeriaTIC fetched and processed.
# Data for evaluon fetched and processed.
# Data for idu-bogota fetched and processed.
# Data for MinistryOfJusticeCZ fetched and processed.
# Data for NLCR fetched and processed.
# Data for opendata-mvcr fetched and processed.
# Data for kb-dk fetched and processed.
# Data for Kortforsyningen fetched and processed.
# Data for NationalMuseumofDenmark fetched and processed.
# Data for Notalib fetched and processed.
# Data for skat fetched and processed.
# Data for ssi-dk fetched and processed.
# Failed to fetch data for StatensMuseumforKunst
# Data for inamhi fetched and processed.
# Failed to fetch data for innovacionsnap
# Data for senescyt fetched and processed.
# Data for informationtechnologyinstitute fetched and processed.
# Data for e-gov fetched and processed.
# Failed to fetch data for kinnisvara
# Data for MKM-ITAO fetched and processed.
# Data for open-eid fetched and processed.
# Data for opendata-ee fetched and processed.
# Data for ethiopian fetched and processed.
# Data for digital-services-act fetched and processed.
# Data for ec-europa fetched and processed.
# Data for eea fetched and processed.
# Data for eu-digital-green-certificates fetched and processed.
# Data for eu-digital-identity-wallet fetched and processed.
# Data for europarl fetched and processed.
# Data for european-central-bank fetched and processed.
# Data for europeana fetched and processed.
# Data for openeuropa fetched and processed.
# Data for 6Aika fetched and processed.
# Data for City-of-Helsinki fetched and processed.
# Data for City-of-Turku fetched and processed.
# Failed to fetch data for CSC-IT-Center-for-Science
# Data for espoon-voltti fetched and processed.
# Data for finnishtransportagency fetched and processed.
# Data for Helsingin-kaupungin-tietokeskus fetched and processed.
# Data for helsinki-city-library fetched and processed.
# Data for HSLdevcom fetched and processed.
# Data for Lounaispaikka fetched and processed.
# Data for lukefi fetched and processed.
# Data for NatLibFi fetched and processed.
# Data for nlsfi fetched and processed.
# Data for opetushallitus fetched and processed.
# Data for sykefi fetched and processed.
# Data for vrk-kpa fetched and processed.
# Data for afimb fetched and processed.
# Data for AlsaceDigitale fetched and processed.
# Data for AmbaNum fetched and processed.
# Data for ansforge fetched and processed.
# Data for ANSSI-FR fetched and processed.
# Data for ApieFrance fetched and processed.
# Data for atih fetched and processed.
# Data for betagouv fetched and processed.
# Data for BRGM fetched and processed.
# Data for cea-hpc fetched and processed.
# Data for cea-leti fetched and processed.
# Data for cea-list fetched and processed.
# Data for cea-sec fetched and processed.
# Data for clipos fetched and processed.
# Data for clipos-archive fetched and processed.
# Data for communaute-cimi fetched and processed.
# Data for culturecommunication fetched and processed.
# Data for cw-leia fetched and processed.
# Data for DGFiP fetched and processed.
# Data for diplomatiegouvfr fetched and processed.
# Data for disic fetched and processed.
# Failed to fetch data for DREAL-NA
# Data for entrepreneur-interet-general fetched and processed.
# Data for erasme fetched and processed.
# Data for etalab fetched and processed.
# Data for Inist-CNRS fetched and processed.
# Data for InseeFr fetched and processed.
# Data for lutece-secteur-public fetched and processed.
# Data for MINAGRI-INITIAL fetched and processed.
# Data for MinistereSupRecherche fetched and processed.
# Data for MTES-MCT fetched and processed.
# Data for nanterre fetched and processed.
# Data for nantesmetropole fetched and processed.
# Data for opencti-platform fetched and processed.
# Data for PnCevennes fetched and processed.
# Data for PnEcrins fetched and processed.
# Data for PnX-SI fetched and processed.
# Data for polewebmaedi fetched and processed.
# Data for ProgrammeVitam fetched and processed.
# Data for region-bretagne fetched and processed.
# Data for sgmap-agd fetched and processed.
# Data for SocialGouv fetched and processed.
# Data for SocieteNumerique fetched and processed.
# Data for strasbourg fetched and processed.
# Data for wookey-project fetched and processed.
# Data for sipf fetched and processed.
# Data for Basisvisualisierung fetched and processed.
# Data for BSI-Bund fetched and processed.
# Data for buehl fetched and processed.
# Data for CERT-Bund fetched and processed.
# Data for corona-warn-app fetched and processed.
# Data for dbmdz fetched and processed.
# Data for Digitaler-Impfnachweis fetched and processed.
# Data for digitalservicebund fetched and processed.
# Data for gbv fetched and processed.
# Data for GovDataOfficial fetched and processed.
# Data for hbz fetched and processed.
# Data for isyfact fetched and processed.
# Data for it-at-m fetched and processed.
# Failed to fetch data for kdn-nrw
# Failed to fetch data for kreis-viersen
# Failed to fetch data for lobid
# Failed to fetch data for Oberverwaltungsgericht-Rheinland-Pfalz
# Failed to fetch data for OpenBfS
# Failed to fetch data for OpenNRW
# Failed to fetch data for regional-digital
# Failed to fetch data for robert-koch-institut
# Failed to fetch data for rostock
# Failed to fetch data for stadt-bielefeld
# Failed to fetch data for stadt-karlsruhe
# Failed to fetch data for StadtBruchsal
# Failed to fetch data for stadtulm
# Failed to fetch data for minfingt
# Failed to fetch data for datagovhk
# Failed to fetch data for fphgov
# Failed to fetch data for DataPortalIndia
# Failed to fetch data for ISRO
# Failed to fetch data for itschool
# Failed to fetch data for npci
# Failed to fetch data for bolsel
# Failed to fetch data for jabardigitalservice
# Failed to fetch data for pemkab-rembang
# Failed to fetch data for EL-BID
# Failed to fetch data for IATI
# Failed to fetch data for ogpl
# Failed to fetch data for HSEIreland
# Failed to fetch data for ogcio
# Failed to fetch data for Isle-Of-Man-Government
# Failed to fetch data for CIOIL
# Failed to fetch data for Digital-Israel
# Failed to fetch data for MohGovIL
# Failed to fetch data for MostIL
# Failed to fetch data for AgID
# Failed to fetch data for ComuneBologna
# Failed to fetch data for Formez
# Failed to fetch data for pcm-dpc
# Failed to fetch data for PloneGov-IT
# Failed to fetch data for RegioneER
# Failed to fetch data for TeamDigitale
# Failed to fetch data for city-of-kobe
# Failed to fetch data for codefornamie
# Failed to fetch data for gsi-cyberjapan
# Failed to fetch data for nhohq
# Failed to fetch data for nims-dpfc
# Failed to fetch data for statesofjersey
# Failed to fetch data for map-ashi
# Failed to fetch data for CSBLatvia
# Failed to fetch data for AplinkosMinisterija
# Failed to fetch data for govlt
# Failed to fetch data for ivpk
# Failed to fetch data for KeliaukLietuvoje
# Failed to fetch data for Nacionaline-sporto-agentura
# Failed to fetch data for viesujupirkimutarnyba
# Failed to fetch data for vilnius
# Failed to fetch data for VMVT-DevHub
# Failed to fetch data for circl
# Failed to fetch data for Geoportail-Luxembourg
# Failed to fetch data for natliblux
# Failed to fetch data for opendatalu
# Failed to fetch data for pmo2
# Failed to fetch data for MUnosecc
# Failed to fetch data for CSB-IG
# Failed to fetch data for DDT-INMEGEN
# Failed to fetch data for IDEA-GTO
# Failed to fetch data for inmegen
# Failed to fetch data for LabLeon
# Failed to fetch data for mxabierto
# Failed to fetch data for PJECZ
# Failed to fetch data for profeco
# Failed to fetch data for redoaxacadetodos
# Failed to fetch data for Amsterdam
# Failed to fetch data for dataoverheid
# Failed to fetch data for GemeenteAlmelo
# Failed to fetch data for GemeenteEde
# Failed to fetch data for Geonovum
# Failed to fetch data for Haarlem
# Failed to fetch data for IenS-Velsen
# Failed to fetch data for KBNLresearch
# Failed to fetch data for Logius-standaarden
# Failed to fetch data for MinBZK
# Failed to fetch data for MinELenI
# Failed to fetch data for minvws
# Failed to fetch data for Pleio
# Failed to fetch data for politie
# Failed to fetch data for provinciegroningen
# Failed to fetch data for provincieNH
# Failed to fetch data for StichtingHergebruikOverheid
# Failed to fetch data for TweedeKamer
# Failed to fetch data for zaanstad
# Failed to fetch data for CanterburyRegionalCouncil
# Failed to fetch data for data-govt-nz
# Failed to fetch data for DigitalNZ
# Failed to fetch data for docgovtnz
# Failed to fetch data for ElectricityAuthority
# Failed to fetch data for GOVTNZ
# Failed to fetch data for linz
# Failed to fetch data for localgovernment
# Failed to fetch data for MfE-NZ
# Failed to fetch data for nz-social-investment-agency
# Failed to fetch data for opcnz
# Failed to fetch data for te-papa
# Failed to fetch data for altinn
# Failed to fetch data for bergenkommune
# Failed to fetch data for brreg
# Failed to fetch data for danskernesdigitalebibliotek
# Failed to fetch data for difi
# Failed to fetch data for digibib
# Failed to fetch data for DirektoratetForByggkvalitet
# Failed to fetch data for dsb-norge
# Failed to fetch data for dss-web
# Failed to fetch data for kartverket
# Failed to fetch data for knreise
# Failed to fetch data for KRD-KOMM-VL
# Failed to fetch data for metno
# Failed to fetch data for miljodir
# Failed to fetch data for nasjonalmuseet
# Failed to fetch data for navikt
# Failed to fetch data for nlbdev
# Failed to fetch data for Nordland-fylkeskommune
# Failed to fetch data for politiet
# Failed to fetch data for Riksrevisjonen
# Failed to fetch data for Rogaland
# Failed to fetch data for rutebanken
# Failed to fetch data for ruterno
# Failed to fetch data for Skatteetaten
# Failed to fetch data for StatensPensjonskasse
# Failed to fetch data for statisticsnorway
# Failed to fetch data for telemark
# Failed to fetch data for telemark-arkiv
# Failed to fetch data for Tolletaten
# Failed to fetch data for uninett
# Failed to fetch data for vegvesen
# Failed to fetch data for IFARHU
# Failed to fetch data for miambiente
# Failed to fetch data for mecpy
# Failed to fetch data for SENATICS
# Failed to fetch data for imarpe
# Failed to fetch data for corcueraromblon
# Failed to fetch data for govph
# Failed to fetch data for igovphil
# Failed to fetch data for Laoag-City
# Failed to fetch data for coi-gov-pl
# Failed to fetch data for Ministerstwo-Cyfryzacji
# Failed to fetch data for nationalmuseum
# Failed to fetch data for amagovpt
# Failed to fetch data for molit-korea
# Failed to fetch data for govro
# Failed to fetch data for MinistryOfLabor
# Failed to fetch data for cikrf
# Failed to fetch data for ghalghai
# Failed to fetch data for kznru
# Failed to fetch data for moscow-technologies
# Failed to fetch data for SAS-NCDC
# Failed to fetch data for dsaidgovsg
# Failed to fetch data for govtechsg
# Failed to fetch data for moexmen
# Failed to fetch data for opengovsg
# Failed to fetch data for slovak-egov
# Failed to fetch data for eddZA
# Failed to fetch data for AjMalgrat
# Data for AjuntamentdeBarcelona fetched and processed.
# Data for AjuntamentdeCalafell fetched and processed.
# Data for AjuntamentdeCastello fetched and processed.
# Data for AjuntamentDeGava fetched and processed.
# Data for AjuntamentDeMataro fetched and processed.
# Data for AjuntamentdeReus fetched and processed.
# Data for AjuntamentdeSabadell fetched and processed.
# Data for AjuntamentdeSantCugat fetched and processed.
# Data for AjuntamentdeTerrassa fetched and processed.
# Data for AyuntamientoMadrid fetched and processed.
# Data for ctt-gob-es fetched and processed.
# Data for ErabakiPamplona fetched and processed.
# Data for gencat fetched and processed.
# Data for GobiernoLaRioja fetched and processed.
# Data for HospitaletDeLlobregat fetched and processed.
# Data for icane fetched and processed.
# Data for lliurex fetched and processed.
# Data for projectestac fetched and processed.
# Data for vilanovailageltru fetched and processed.
# Data for Alingsas-Kommun fetched and processed.
# Data for arbetsformedlingen fetched and processed.
# Data for domstol fetched and processed.
# Data for dotse fetched and processed.
# Data for elegnamnden fetched and processed.
# Data for Forsakringskassan fetched and processed.
# Data for gbif-sweden fetched and processed.
# Data for Helsingborg fetched and processed.
# Data for helsingborg-stad fetched and processed.
# Data for ISOF-ITD fetched and processed.
# Data for jobtechswe fetched and processed.
# Data for kungbib fetched and processed.
# Data for Lantmateriet fetched and processed.
# Data for libris fetched and processed.
# Data for lldd fetched and processed.
# Data for lshSWE fetched and processed.
# Data for malmostad fetched and processed.
# Data for mtmse fetched and processed.
# Data for NationalmuseumSWE fetched and processed.
# Data for NordicMuseum fetched and processed.
# Data for regionhalland fetched and processed.
# Data for regionostergotland fetched and processed.
# Data for riksantikvarieambetet fetched and processed.
# Data for riksarkivet fetched and processed.
# Data for rinfo fetched and processed.
# Data for sambruk fetched and processed.
# Data for SciLifeLab fetched and processed.
# Data for SICS fetched and processed.
# Data for skolverket fetched and processed.
# Data for smhi fetched and processed.
# Data for SodertornHB fetched and processed.
# Data for statens-maritima-museer fetched and processed.
# Data for statisticssweden fetched and processed.
# Data for Sundsvallskommun fetched and processed.
# Data for Sunet fetched and processed.
# Data for sverigesradio fetched and processed.
# Data for SVT fetched and processed.
# Data for SwedenConnect fetched and processed.
# Data for swedish-council-for-higher-education fetched and processed.
# Data for swedishpensionsagency fetched and processed.
# Data for The-Municipality-of-Staffanstorp fetched and processed.
# Data for umea-kommun fetched and processed.
# Data for Vastra-Gotalandsregionen fetched and processed.
# Data for vasttrafik fetched and processed.
# Data for admin-ch fetched and processed.
# Data for alv-ch fetched and processed.
# Failed to fetch data for BFS-SHS-MSAS
# Data for dsi-vd fetched and processed.
# Data for FNSKtZH fetched and processed.
# Data for geoadmin fetched and processed.
# Data for gisktzh fetched and processed.
# Data for kanton-aargau fetched and processed.
# Data for kanton-bern fetched and processed.
# Data for metas-ch fetched and processed.
# Data for ogdch fetched and processed.
# Data for ogdtg fetched and processed.
# Data for opendatabs fetched and processed.
# Data for opendatazurich fetched and processed.
# Data for openZH fetched and processed.
# Data for SFOE fetched and processed.
# Data for sitn fetched and processed.
# Data for statistikstadtzuerich fetched and processed.
# Data for statistikZH fetched and processed.
# Data for VerkehrsbetriebeZuerich fetched and processed.
# Data for moda-gov-tw fetched and processed.
# Data for pdis fetched and processed.
# Data for taipei-doit fetched and processed.
# Failed to fetch data for taipeicity
# Data for DGA-Thailand fetched and processed.
# Data for 111online fetched and processed.
# Data for acteng fetched and processed.
# Data for alphagov fetched and processed.
# Data for BEACmodel fetched and processed.
# Data for britishlibrary fetched and processed.
# Data for cabinetoffice fetched and processed.
# Data for CDPS-Wales fetched and processed.
# Data for CJSCommonPlatform fetched and processed.
# Data for co-cddo fetched and processed.
# Data for communitiesuk fetched and processed.
# Data for companieshouse fetched and processed.
# Data for CPS-Innovation fetched and processed.
# Data for datagovuk fetched and processed.
# Data for datasciencecampus fetched and processed.
# Data for decc fetched and processed.
# Data for defra fetched and processed.
# Data for DFE-Digital fetched and processed.
# Data for dfid fetched and processed.
# Data for digital-preservation fetched and processed.
# Failed to fetch data for directgov-innovate
# Data for dstl fetched and processed.
# Data for dvla fetched and processed.
# Data for dvsa fetched and processed.
# Data for dwp fetched and processed.
# Data for GCHQ fetched and processed.
# Data for gds-dead fetched and processed.
# Data for gds-operations fetched and processed.
# Data for govuk-one-login fetched and processed.
# Data for guidance-guarantee-programme fetched and processed.
# Data for hmcts fetched and processed.
# Data for HMPO fetched and processed.
# Data for hmrc fetched and processed.
# Data for HO-CTO fetched and processed.
# Data for houseofcommonslibrary fetched and processed.
# Data for i-dot-ai fetched and processed.
# Data for informatics-lab fetched and processed.
# Data for insolvencyservice fetched and processed.
# Data for intellectual-property-office fetched and processed.
# Data for IQuOD fetched and processed.
# Data for jncc fetched and processed.
# Data for JNCC-UK fetched and processed.

# %%
repos_df = pd.DataFrame(all_repos)
repos_df
# Out:
#                                       name  \
# 0                        accesibilidad-web
# 1                    AR-API-Gateway-Distro
# 2                                AR-Distro
# 3                   barra-de-accesibilidad
# 4                                    cofra
# ...                                    ...
# 2139                         laws-lois-xml
# 2140                          lims-xml-dtd
# 2141  ogd-office-entry-am-entree-au-bureau
# 2142                                  otto
# 2143                     welcome-bienvenue
#
#                                             description  stars  forks  \
# 0     Repositorio del Equipo de Accesibilidad Web de...     66     19
# 1                                        No description      0      1
# 2                       Distro de Drupal para Gobiernos     12     10
# 3     Plugin que incorpora opciones de accesibilidad...      5      6
# 4                    Sistema de rendición de caja chica      3      5
# ...                                                 ...    ...    ...
# 2139  The consolidated Acts and regulations of Canad...     13      0
# 2140  The xml document type definitions for the fede...      0      0
# 2141           COVID-19 Office Entry - Entrée au bureau     10      4
# 2142                                     No description      1      0
# 2143  Readme for the Department of Justice Canada Gi...      1      1
#
#             language                                             readme
# 0     None specified  # Accesibilidad Web\n\n**Repositorio del Equip...
# 1     None specified                            # AR-API-Gateway-Distro
# 2                PHP  # AR-Distro\n\nDistribución Drupal gratuita de...
# 3                PHP  # Barra de "Herramientas de Accesibilidad"\n# ...
# 4                PHP  # Cofra\n\nSistema de rendición de caja chica....
# ...              ...                                                ...
# 2139            XSLT  # laws-lois-xml - [Aller en français](https://...
# 2140  None specified                               README not available
# 2141      PowerShell  # COVID-19 Office Entry - Entrée au bureau\nTh...
# 2142          Python  # What is Otto\n\nOtto is a suite of AI servic...
# 2143  None specified  # welcome-bienvenue\nReadme for the Department...
#
# [2144 rows x 6 columns]

# %%
repos_df10 = repos_df[:10]

# %%
# !pip install langchain langchain-anthropic langchain-community
# Out:
# python(95213) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: langchain in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (0.3.3)
# Requirement already satisfied: langchain-anthropic in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (0.2.3)
# Collecting langchain-community
#   Downloading langchain_community-0.3.2-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 9.2 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (0.3.10)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: numpy<2,>=1 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (0.1.135)
# Requirement already satisfied: requests<3,>=2 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: anthropic<1,>=0.30.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain-anthropic) (0.36.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain-anthropic) (0.7.1)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.15.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.6.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.27.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: sniffio in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.20.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (4.6.2.post1)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.5 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.30.0->langchain-anthropic) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain-anthropic) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain-anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (0.25.2)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: propcache>=0.2.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: filelock in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (2024.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/alexander.deville/.pyenv/versions/3.10.11/envs/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (4.66.5)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.3.2 marshmallow-3.22.0 mypy-extensions-1.0.0 pydantic-settings-2.5.2 typing-inspect-0.9.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain.prompts import PromptTemplate
from langchain_anthropic import ChatAnthropic
from tqdm import tqdm
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain_core.exceptions import OutputParserException

anthropic_api_key = os.getenv('ANTHROPIC_KEY')
df = repos_df.copy()

def classify_repos(df, topic_list, model_name="claude-3-haiku-20240307"):
    llm = ChatAnthropic(model=model_name, api_key=anthropic_api_key)
    
    summary_prompt = PromptTemplate(
        input_variables=["description", "readme"],
        template="""
        Please provide a summary of the following GitHub repository based on its description and README.md content. If the README.md is not in English, please first translate it to English and then generate a summary. The summary should be concise and in fewer than 5 sentences.
        
        Repository description:
        {description}
        
        README.md content:
        {readme}
        
        Summary:
        """
    )
    
    topic_prompt = PromptTemplate(
        input_variables=["summary", "topic_list"],
        template="""
        Given the following summary of a GitHub repository and a list of potential topics, select the most appropriate topic for the repository. If none of the topics in the list are suitable, generate a new topic label.
        
        Repository summary:
        {summary}
        
        Potential topics:
        {topic_list}
        
        Selected topic:
        """
    )
    
    def generate_summary(row):
        description = row["description"] if pd.notnull(row["description"]) else ""
        readme = row["readme"] if pd.notnull(row["readme"]) else ""
        prompt = summary_prompt.format(description=description, readme=readme)
        summary = llm.invoke(prompt).content
        return summary
    
    response_schemas = [
        ResponseSchema(name="topic", description="The selected topic for the repository.")
    ]
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

    topic_prompt = PromptTemplate(
        input_variables=["summary", "topic_list"],
        template="""
        Given the following summary of a GitHub repository and a list of potential topics, select the most appropriate topic for the repository. If none of the topics in the list are suitable, generate a new topic label.

        Repository summary:
        {summary}

        Potential topics:
        {topic_list}

        Selected topic:
        "{{topic}}"

        PLEASE ONLY RETURN THE TOPIC LABEL AS THE RESPONSE. DO NOT INCLUDE ANY ADDITIONAL TEXT.
        """,
        output_parser=output_parser,
    )

    def classify_repo(readme):
        row = df.loc[df["readme"] == readme].iloc[0]
        summary = generate_summary(row)
        prompt = topic_prompt.format(summary=summary, topic_list=", ".join(topic_list))
        response = llm.invoke(prompt).content

        try:
            topic = output_parser.parse(response)["topic"]
        except OutputParserException:
            # Handle the case when the response is not a valid JSON
            topic = response.strip()  # Extract the topic as a plain string

        if topic not in topic_list:
            topic_list.append(topic)

        return topic
    
    tqdm.pandas(desc="Classifying repositories")
    df["topic"] = df["readme"].progress_apply(classify_repo)
    
    df["summary"] = df.apply(generate_summary, axis=1)
    
    return df, topic_list

# %%
display(df)
# Out:
#                         name  \
# 0          accesibilidad-web
# 1      AR-API-Gateway-Distro
# 2                  AR-Distro
# 3     barra-de-accesibilidad
# 4                      cofra
# 5             cuidar-android
# 6                 cuidar-ios
# 7  drupal-argentina-borrador
# 8  drupal-argentina-carousel
# 9    drupal-argentina-distro
#
#                                          description  stars  forks  \
# 0  Repositorio del Equipo de Accesibilidad Web de...     66     19
# 1                                     No description      0      1
# 2                    Distro de Drupal para Gobiernos     12     10
# 3  Plugin que incorpora opciones de accesibilidad...      5      6
# 4                 Sistema de rendición de caja chica      3      5
# 5                                         App Cuidar     74     21
# 6                                         App Cuidar     12      5
# 7  Esta es una distribución de un componente util...      0      1
# 8  Esta es una distribución de un componente util...      0      1
# 9  Esta es una distribución pública del portal de...      0      1
#
#          language                                             readme
# 0  None specified  # Accesibilidad Web\n\n**Repositorio del Equip...
# 1  None specified                            # AR-API-Gateway-Distro
# 2             PHP  # AR-Distro\n\nDistribución Drupal gratuita de...
# 3             PHP  # Barra de "Herramientas de Accesibilidad"\n# ...
# 4             PHP  # Cofra\n\nSistema de rendición de caja chica....
# 5            Java  # Cuidar Android\n\nSe publica aquí el código ...
# 6           Swift  # Cuidar iOS\n\nSe publica aquí el código fuen...
# 7             PHP  # drupal-argentina-borrador\nEsta es una distr...
# 8             PHP  # drupal-argentina-carousel\nEsta es una distr...
# 9             PHP  # drupal-argentina-distro\nEsta es una distrib...

# %%
df, topic_list = classify_repos(repos_df10, topic_list=['ai', 'web development', 'data science', 'cybersecurity'])
df
df.to_csv('all_gov_projects.csv', index=False)
# Out:
# Classifying repositories: 100%|██████████| 10/10 [00:17<00:00,  1.74s/it]
# /var/folders/3g/3t5s674944ngc36ptbb_hf10dwg8q4/T/ipykernel_76049/413614417.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["topic"] = df["readme"].progress_apply(classify_repo)
# /var/folders/3g/3t5s674944ngc36ptbb_hf10dwg8q4/T/ipykernel_76049/413614417.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["summary"] = df.apply(generate_summary, axis=1)

# %%
import requests
import yaml
import os
from dotenv import load_dotenv

def fetch_gov_github_accounts(url):
    response = requests.get(url)
    if response.status_code == 200:
        return yaml.safe_load(response.text)
    else:
        return None

def fetch_repository_details(username, token):
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    repos_response = requests.get(repos_url, headers=headers)
    
    if repos_response.status_code == 200:
        repos_data = repos_response.json()
        full_repo_details = []
        
        for repo in repos_data:
            repo_details = {
                'name': repo['name'],
                'description': repo['description'] or "No description",
                'stars': repo['stargazers_count'],
                'forks': repo['forks'],
                'language': repo['language'] or "None specified"
            }
            # Fetch the README file
            readme_url = f"https://api.github.com/repos/{username}/{repo['name']}/readme"
            readme_response = requests.get(readme_url, headers=headers)
            if readme_response.status_code == 200:
                readme_data = readme_response.json()
                readme_content = requests.get(readme_data['download_url']).text
                repo_details['readme'] = readme_content[:100]  # Truncate for brevity
            else:
                repo_details['readme'] = "README not available"
            
            full_repo_details.append(repo_details)
        
        return full_repo_details
    else:
        return None

def save_to_markdown(repos, filename):
    with open(filename, 'w') as f:
        f.write('| Repository Name | Description | Stars | Language | README |\n')
        f.write('|-----------------|-------------|-------|----------|--------|\n')
        for repo in repos:
            f.write(f"| {repo['name']} | {repo['description']} | {repo['stars']} | {repo['language']} | {repo['readme'][:50]}... |\n")


# Load environment variables from .env file
load_dotenv('.env')

# Access environment variables
github_token = os.getenv('GITHUB_TOKEN')


# Main execution
url = "https://raw.githubusercontent.com/github/government.github.com/gh-pages/_data/governments.yml"
accounts = fetch_gov_github_accounts(url)

accounts
# Out:
# {'Argentina': ['argob',
#   'cifasis',
#   'gcba',
#   'inti-cmnb',
#   'municipalidad-de-vicente-lopez',
#   'municipioriogrande'],
#  'Australia': ['actesa',
#   'actgov',
#   'agnsw',
#   'AtlasOfLivingAustralia',
#   'ausdto',
#   'australianantarcticdatacentre',
#   'AustralianAntarcticDivision',
#   'berowrarfb',
#   'bom-radar',
#   'city-of-melbourne',
#   'commerce-wa-ols',
#   'consumerdataright',
#   'data61',
#   'datagovau',
#   'dbca-wa',
#   'dpc-sdp',
#   'dpipwe',
#   'dssgovaus',
#   'envris',
#   'Fire-and-Rescue-NSW',
#   'gccgisteam',
#   'GeoscienceAustralia',
#   'govau',
#   'govcms',
#   'gs-dawr',
#   'healthgovau',
#   'Healthway',
#   'hiscom',
#   'innovationgovau',
#   'IPAustralia',
#   'Landgate',
#   'nla',
#   'NSW-eTendering',
#   'NSWPlanning',
#   'pmcau',
#   'PublicRecordOfficeVictoria',
#   'qld-gov-au',
#   'srnsw',
#   'SunshineCoastCouncil',
#   'treasury-aus',
#   'victoriangovernment',
#   'wagov',
#   'wamuseum'],
#  'Austria': ['datagvat'],
#  'Belgium': ['belgianpolice',
#   'CIRB',
#   'Fedict',
#   'inbo',
#   'NationalBankBelgium',
#   'onroerenderfgoed',
#   'StadGent'],
#  'Bolivia': ['adsib', 'geobolivia'],
#  'Brazil': ['bacendeinf',
#   'camaradosdeputadosoficial',
#   'cenima-ibama',
#   'cislgov',
#   'culturagovbr',
#   'dadosgovbr',
#   'dataprev',
#   'EscolaDeSaudePublica',
#   'fablablivresp',
#   'fateczonaleste',
#   'gabinetedigital',
#   'govbr',
#   'GovBrasil',
#   'imagov',
#   'InstitutoBenjaminConstant',
#   'interlegis',
#   'justicagovbr',
#   'labhackercd',
#   'lexml',
#   'MP-ES',
#   'MP-RJ',
#   'pensandoodireito',
#   'plonegovbr',
#   'pr-snas',
#   'prefeitura-rio',
#   'prefeiturasp',
#   'PROCERGS',
#   'prodest',
#   'secom-tocantins',
#   'secultce',
#   'sepinf-inc',
#   'servicosgovbr',
#   'tcers',
#   'tisorocaba',
#   'tre-pa',
#   'wpgovbr'],
#  'Bulgaria': ['govbg', 'governmentbg'],
#  'Cambodia': ['e-Government-Cambodia'],
#  'Canada': ['AAFC-MBB',
#   'abgov',
#   'asc-csa',
#   'bac-lac',
#   'BCGov',
#   'canada-ca',
#   'cds-snc',
#   'CityofEdmonton',
#   'cityofgreatersudbury',
#   'cityofottawa',
#   'CityOfSarnia',
#   'cityofsurrey',
#   'CityofToronto',
#   'cityssm',
#   'cngo',
#   'CommunicationSecurityEstablishment',
#   'csbp-cpse',
#   'CSPS-EFPC-DAAN',
#   'CybercentreCanada',
#   'ECCC-MSC',
#   'eodms-sgdot',
#   'esdc-devx',
#   'esdc-edsc',
#   'ExchangeBC',
#   'fgpv-vpgf',
#   'gc-proto',
#   'GCTC-NTGC',
#   'gctools-outilsgc',
#   'GeoCanViz',
#   'GNWT',
#   'GovAlta',
#   'infra-geo-ouverte',
#   'justicecanada',
#   'LMID-DIMT',
#   'MC-MBO-WebPublishingTeam',
#   'MetPX',
#   'MTS-STM',
#   'nrc-cnrc',
#   'NRCan',
#   'nsgov',
#   'ongov',
#   'open-data',
#   'phac-aspc',
#   'phac-nml',
#   'PHACDataHub',
#   'pspc-spac',
#   'PSPC-SPAC-buyandsell',
#   'RAMP-PCAR',
#   'RDOQ',
#   'ServiceCanada',
#   'StatCan',
#   'TBS-EACPD',
#   'tc-ca',
#   'veteransaffairscanada',
#   'VilledeMontreal',
#   'wet-boew'],
#  'Chile': ['e-gob'],
#  'Colombia': ['AltaConsejeriaTIC', 'evaluon', 'idu-bogota'],
#  'Czech Republic': ['MinistryOfJusticeCZ', 'NLCR', 'opendata-mvcr'],
#  'Denmark': ['kb-dk',
#   'Kortforsyningen',
#   'NationalMuseumofDenmark',
#   'Notalib',
#   'skat',
#   'ssi-dk',
#   'StatensMuseumforKunst'],
#  'Ecuador': ['inamhi', 'innovacionsnap', 'senescyt'],
#  'Egypt': ['informationtechnologyinstitute'],
#  'Estonia': ['e-gov', 'kinnisvara', 'MKM-ITAO', 'open-eid', 'opendata-ee'],
#  'Ethiopia': ['ethiopian'],
#  'European Union': ['digital-services-act',
#   'ec-europa',
#   'eea',
#   'eu-digital-green-certificates',
#   'eu-digital-identity-wallet',
#   'europarl',
#   'european-central-bank',
#   'europeana',
#   'openeuropa'],
#  'Finland': ['6Aika',
#   'City-of-Helsinki',
#   'City-of-Turku',
#   'CSC-IT-Center-for-Science',
#   'espoon-voltti',
#   'finnishtransportagency',
#   'Helsingin-kaupungin-tietokeskus',
#   'helsinki-city-library',
#   'HSLdevcom',
#   'Lounaispaikka',
#   'lukefi',
#   'NatLibFi',
#   'nlsfi',
#   'opetushallitus',
#   'sykefi',
#   'vrk-kpa'],
#  'France': ['afimb',
#   'AlsaceDigitale',
#   'AmbaNum',
#   'ansforge',
#   'ANSSI-FR',
#   'ApieFrance',
#   'atih',
#   'betagouv',
#   'BRGM',
#   'cea-hpc',
#   'cea-leti',
#   'cea-list',
#   'cea-sec',
#   'clipos',
#   'clipos-archive',
#   'communaute-cimi',
#   'culturecommunication',
#   'cw-leia',
#   'DGFiP',
#   'diplomatiegouvfr',
#   'disic',
#   'DREAL-NA',
#   'entrepreneur-interet-general',
#   'erasme',
#   'etalab',
#   'Inist-CNRS',
#   'InseeFr',
#   'lutece-secteur-public',
#   'MINAGRI-INITIAL',
#   'MinistereSupRecherche',
#   'MTES-MCT',
#   'nanterre',
#   'nantesmetropole',
#   'opencti-platform',
#   'PnCevennes',
#   'PnEcrins',
#   'PnX-SI',
#   'polewebmaedi',
#   'ProgrammeVitam',
#   'region-bretagne',
#   'sgmap-agd',
#   'SocialGouv',
#   'SocieteNumerique',
#   'strasbourg',
#   'wookey-project'],
#  'French Polynesia': ['sipf'],
#  'Germany': ['Basisvisualisierung',
#   'BSI-Bund',
#   'buehl',
#   'CERT-Bund',
#   'corona-warn-app',
#   'dbmdz',
#   'Digitaler-Impfnachweis',
#   'digitalservicebund',
#   'gbv',
#   'GovDataOfficial',
#   'hbz',
#   'isyfact',
#   'it-at-m',
#   'kdn-nrw',
#   'kreis-viersen',
#   'lobid',
#   'OpenBfS',
#   'OpenNRW',
#   'regional-digital',
#   'robert-koch-institut',
#   'rostock',
#   'stadt-bielefeld',
#   'stadt-karlsruhe',
#   'StadtBruchsal',
#   'stadtulm'],
#  'Guatemala': ['minfingt'],
#  'Hong Kong': ['datagovhk'],
#  'Hungary': ['fphgov'],
#  'India': ['DataPortalIndia', 'ISRO', 'itschool', 'npci'],
#  'Indonesia': ['bolsel', 'jabardigitalservice', 'pemkab-rembang'],
#  'International': ['EL-BID', 'IATI', 'ogpl'],
#  'Ireland': ['HSEIreland'],
#  'Isle of Man': ['Isle-Of-Man-Government'],
#  'Israel': ['CIOIL', 'Digital-Israel', 'MohGovIL', 'MostIL'],
#  'Italy': ['AgID',
#   'ComuneBologna',
#   'Formez',
#   'pcm-dpc',
#   'PloneGov-IT',
#   'RegioneER',
#   'TeamDigitale'],
#  'Japan': ['city-of-kobe',
#   'codefornamie',
#   'gsi-cyberjapan',
#   'nhohq',
#   'nims-dpfc',
#   'wakayama-pref-org'],
#  'Jersey': ['statesofjersey'],
#  'Kosovo': ['map-ashi'],
#  'Latvia': ['CSBLatvia'],
#  'Lithuania': ['AplinkosMinisterija',
#   'govlt',
#   'ivpk',
#   'viesujupirkimutarnyba',
#   'vilnius'],
#  'Luxemburg': ['circl', 'Geoportail-Luxembourg', 'natliblux', 'opendatalu'],
#  'Malaysia': ['pmo2'],
#  'Mauritius': ['MUnosecc'],
#  'Mexico': ['CSB-IG',
#   'DDT-INMEGEN',
#   'inmegen',
#   'LabLeon',
#   'mxabierto',
#   'PJECZ',
#   'profeco',
#   'redoaxacadetodos'],
#  'Netherlands': ['Amsterdam',
#   'dataoverheid',
#   'GemeenteAlmelo',
#   'GemeenteEde',
#   'gemeentemuseum',
#   'Geonovum',
#   'Haarlem',
#   'IenS-Velsen',
#   'KBNLresearch',
#   'Logius-standaarden',
#   'MinBZK',
#   'MinELenI',
#   'minvws',
#   'Pleio',
#   'provinciegroningen',
#   'provincieNH',
#   'StichtingHergebruikOverheid',
#   'TweedeKamer',
#   'zaanstad'],
#  'New Zealand': ['CanterburyRegionalCouncil',
#   'data-govt-nz',
#   'DigitalNZ',
#   'docgovtnz',
#   'ElectricityAuthority',
#   'GOVTNZ',
#   'linz',
#   'localgovernment',
#   'MfE-NZ',
#   'nz-social-investment-agency',
#   'opcnz',
#   'te-papa'],
#  'Norway': ['altinn',
#   'bergenkommune',
#   'brreg',
#   'difi',
#   'digibib',
#   'DirektoratetForByggkvalitet',
#   'dsb-norge',
#   'dss-web',
#   'kartverket',
#   'knreise',
#   'KRD-KOMM-VL',
#   'metno',
#   'miljodir',
#   'nasjonalmuseet',
#   'navikt',
#   'nlbdev',
#   'Nordland-fylkeskommune',
#   'politiet',
#   'Riksrevisjonen',
#   'Rogaland',
#   'rutebanken',
#   'ruterno',
#   'Skatteetaten',
#   'StatensPensjonskasse',
#   'statisticsnorway',
#   'telemark',
#   'telemark-arkiv',
#   'Tolletaten',
#   'uninett',
#   'vegvesen'],
#  'Panama': ['IFARHU', 'miambiente'],
#  'Paraguay': ['mecpy', 'SENATICS'],
#  'Peru': ['imarpe'],
#  'Philippines': ['corcueraromblon', 'govph', 'igovphil', 'Laoag-City'],
#  'Poland': ['coi-gov-pl', 'Ministerstwo-Cyfryzacji', 'nationalmuseum'],
#  'Portugal': ['amagovpt'],
#  'Republic of Korea': ['molit-korea'],
#  'Romania': ['govro', 'MinistryOfLabor'],
#  'Russia': ['cikrf', 'ghalghai', 'kznru', 'moscow-technologies'],
#  'Saudi Arabia': ['SAS-NCDC'],
#  'Singapore': ['dsaidgovsg', 'govtechsg', 'moexmen', 'opengovsg'],
#  'Slovakia': ['slovak-egov'],
#  'South Africa': ['eddZA'],
#  'Spain': ['AjMalgrat',
#   'AjuntamentdeBarcelona',
#   'AjuntamentdeCalafell',
#   'AjuntamentdeCastello',
#   'AjuntamentDeGava',
#   'AjuntamentDeMataro',
#   'AjuntamentdeReus',
#   'AjuntamentdeSabadell',
#   'AjuntamentdeSantCugat',
#   'AjuntamentdeTerrassa',
#   'AyuntamientoMadrid',
#   'ctt-gob-es',
#   'ErabakiPamplona',
#   'gencat',
#   'GobiernoLaRioja',
#   'HospitaletDeLlobregat',
#   'icane',
#   'lliurex',
#   'projectestac',
#   'vilanovailageltru'],
#  'Sweden': ['Alingsas-Kommun',
#   'arbetsformedlingen',
#   'domstol',
#   'dotse',
#   'elegnamnden',
#   'Forsakringskassan',
#   'gbif-sweden',
#   'Helsingborg',
#   'helsingborg-stad',
#   'ISOF-ITD',
#   'jobtechswe',
#   'kungbib',
#   'Lantmateriet',
#   'libris',
#   'lldd',
#   'lshSWE',
#   'malmostad',
#   'mtmse',
#   'NationalmuseumSWE',
#   'NordicMuseum',
#   'regionhalland',
#   'regionostergotland',
#   'riksantikvarieambetet',
#   'riksarkivet',
#   'rinfo',
#   'sambruk',
#   'SciLifeLab',
#   'SICS',
#   'skolverket',
#   'smhi',
#   'SodertornHB',
#   'statens-maritima-museer',
#   'Statenspersonadressregister',
#   'statisticssweden',
#   'Sundsvallskommun',
#   'Sunet',
#   'sverigesradio',
#   'SVT',
#   'SwedenConnect',
#   'swedish-council-for-higher-education',
#   'swedishpensionsagency',
#   'The-Municipality-of-Staffanstorp',
#   'umea-kommun',
#   'Vastra-Gotalandsregionen',
#   'vasttrafik'],
#  'Switzerland': ['admin-ch',
#   'alv-ch',
#   'BFS-SHS-MSAS',
#   'dsi-vd',
#   'FNSKtZH',
#   'geoadmin',
#   'gisktzh',
#   'kanton-aargau',
#   'kanton-bern',
#   'metas-ch',
#   'ogdch',
#   'ogdtg',
#   'opendatabs',
#   'opendatazurich',
#   'openZH',
#   'SFOE',
#   'sitn',
#   'statistikstadtzuerich',
#   'statistikZH',
#   'VerkehrsbetriebeZuerich'],
#  'Taiwan': ['moda-gov-tw', 'pdis', 'taipeicity'],
#  'Thailand': ['DGA-Thailand'],
#  'U.K. Central': ['111online',
#   'alphagov',
#   'BEACmodel',
#   'britishlibrary',
#   'cabinetoffice',
#   'CDPS-Wales',
#   'CJSCommonPlatform',
#   'co-cddo',
#   'communitiesuk',
#   'companieshouse',
#   'CPS-Innovation',
#   'datagovuk',
#   'datasciencecampus',
#   'decc',
#   'defra',
#   'DFE-Digital',
#   'dfid',
#   'digital-preservation',
#   'directgov-innovate',
#   'dstl',
#   'dvla',
#   'dvsa',
#   'dwp',
#   'GCHQ',
#   'gds-dead',
#   'gds-operations',
#   'govuk-one-login',
#   'guidance-guarantee-programme',
#   'hmcts',
#   'HMPO',
#   'hmrc',
#   'HO-CTO',
#   'houseofcommonslibrary',
#   'informatics-lab',
#   'insolvencyservice',
#   'intellectual-property-office',
#   'IQuOD',
#   'jncc',
#   'JNCC-UK',
#   'jules-lsm',
#   'LandRegistry',
#   'landregistry-ops',
#   'lgss',
#   'LocalGovDigital',
#   'MarineScotlandScience',
#   'MetOffice',
#   'MetOfficeSpaceApps',
#   'metomi',
#   'MHRA',
#   'ministryofjustice',
#   'moj-analytical-services',
#   'naouk',
#   'nationalarchives',
#   'NationalCrimeAgency',
#   'NationalLibraryOfScotland',
#   'nhsconnect',
#   'nhsdigital',
#   'nhsengland',
#   'nhsuk',
#   'NHSX',
#   'nice-digital',
#   'nihp-public',
#   'OfqualGovUK',
#   'ONSdigital',
#   'openregister',
#   'osgeouk',
#   'scottishgovernment',
#   'SkillsFundingAgency',
#   'tanc-ahrc',
#   'ukforeignoffice',
#   'ukgovdatascience',
#   'UKGovernmentBEIS',
#   'UKHomeOffice',
#   'UKHomeOfficeForms',
#   'UKLocation',
#   'ukncsc',
#   'uktrade',
#   'ukwa'],
#  'U.K. Councils': ['BathnesDevelopment',
#   'BracknellForestCouncil',
#   'brighton-hove-gov-uk',
#   'BristolCityCouncil',
#   'CamdenCouncil',
#   'cityofyork',
#   'devoncc',
#   'DevonCountyCouncil',
#   'Dorset-Council-UK',
#   'DundeeCityCouncil',
#   'east-sussex-county-council',
#   'edinburghcouncil',
#   'essexcountycouncil',
#   'gmfrs',
#   'GuildfordBC',
#   'HfdsCouncil',
#   'kentcc',
#   'LambethCouncil',
#   'lichfield-district-council',
#   'LondonBoroughSutton',
#   'LutonCouncil',
#   'openglasgow',
#   'RotherDC',
#   'RoyalBoroughKingston',
#   'smbc-digital',
#   'surreydigitalservices',
#   'thehighlandcouncil',
#   'TraffordCouncil',
#   'warwickshire',
#   'wealden',
#   'west-berkshire-council',
#   'wmfs'],
#  'U.S. City': ['austincodeit',
#   'Baltimore-City-EGIS',
#   'berkeleypubliclibrary',
#   'BostonRedevelop',
#   'cambridgedata',
#   'cambridgegis',
#   'chicago',
#   'city-of-bellingham',
#   'city-of-bloomington',
#   'cityofasheville',
#   'CityOfAuburnAL',
#   'cityofaustin',
#   'cityofboise',
#   'CityOfBoston',
#   'cityofboulder',
#   'cityofburlington',
#   'cityofchattanooga',
#   'CityOfDetroit',
#   'CityOfLosAngeles',
#   'cityofnewyork',
#   'CityOfPhiladelphia',
#   'CityofPittsburgh',
#   'cityofportland',
#   'CityofReno',
#   'CityofSanFrancisco',
#   'CityofSantaMonica',
#   'cityofsomerville',
#   'cityofvernonia',
#   'CityOfVirginiaBeach',
#   'cityofwestsacramento',
#   'CityofYakima',
#   'cno-opa',
#   'CORaleigh',
#   'CUMTD',
#   'DCCouncil',
#   'DCgov',
#   'DenverDev',
#   'digitalinclusion',
#   'egovpdx',
#   'Honolulu',
#   'kcmo',
#   'lfucg',
#   'longbeachinnovationteam',
#   'LouisvilleMetro',
#   'louisvillemetro-innovation',
#   'mnhrc',
#   'mnylc',
#   'moda-nyc',
#   'monum',
#   'NewYorkCityCouncil',
#   'NYCComptroller',
#   'nycdot',
#   'NYCPlanning',
#   'onc-healthit',
#   'OpenGovDC',
#   'p2g',
#   'pdxgis',
#   'PierceCountyWA',
#   'ProBonoDC',
#   'ridertd',
#   'SantaClarita',
#   'sfbart',
#   'SiloamSprings',
#   'southbendin',
#   'TownOfBrookline',
#   'tucsonaz'],
#  'U.S. County': ['anoka-script-team',
#   'ArlingtonCounty',
#   'baltimorecounty',
#   'BayAreaMetro',
#   'bouldercounty',
#   'CanyonCounty',
#   'CarverCounty',
#   'donaanacounty',
#   'fairfieldcountyit',
#   'fpdcc',
#   'HarrisCountyFOA',
#   'HennepinCountyPublicDefender',
#   'LACMTA',
#   'MCLD',
#   'pottcountyit',
#   'saccounty',
#   'sfcta',
#   'slugis'],
#  'U.S. Federal': ['18f',
#   'adl-aicc',
#   'adlnet',
#   'afrl',
#   'arcticlcc',
#   'BBGInnovate',
#   'bfelob',
#   'blue-button',
#   'businessusa',
#   'CA-CST-Library',
#   'CA-CST-SII',
#   'ccmc',
#   'CDCgov',
#   'cfpb',
#   'cigiegov',
#   'cisagov',
#   'cloud-gov',
#   'cmsgov',
#   'commercedataservice',
#   'commercegov',
#   'demand-driven-open-data',
#   'department-of-veterans-affairs',
#   'didsr',
#   'digital-analytics-program',
#   'dodcio',
#   'doecode',
#   'doi-open-data',
#   'EEOC',
#   'energyapps',
#   'erdc',
#   'eregs',
#   'FAA-Aviation-Data-Portal',
#   'fcc',
#   'fda',
#   'fecgov',
#   'Federal-Aviation-Administration',
#   'federal-courts-software-factory',
#   'federaltradecommission',
#   'fedspendingtransparency',
#   'firelab',
#   'globegit',
#   'gopleader',
#   'government-services',
#   'GrainGenes',
#   'gsa',
#   'gsa-oes',
#   'hhs',
#   'HHS-AHRQ',
#   'HHSDigitalMediaAPIPlatform',
#   'HHSIDEAlab',
#   'historyatstate',
#   'IIP-Design',
#   'IMDProjects',
#   'imls',
#   'informaticslab',
#   'Innovation-Toolkit',
#   'internationaltradeadministration',
#   'ioos',
#   'IRSgov',
#   'keplergo',
#   'libraryofcongress',
#   'M-O-S-E-S',
#   'mcc-gov',
#   'missioncommand',
#   'nasa',
#   'nasa-develop',
#   'nasa-gibs',
#   'NASA-rdt',
#   'nasa-tournament-lab',
#   'nasaworldwind',
#   'NationalGuard',
#   'nationalparkservice',
#   'navadmc',
#   'NCRN',
#   'NeoGeographyToolkit',
#   'nesii',
#   'ngds',
#   'nhanes',
#   'nidcd',
#   'NIEM',
#   'NMB-Dev',
#   'NMML',
#   'NOAA-EPIC',
#   'noaa-gfdl',
#   'NOAA-ORR-ERD',
#   'noaa-pmel',
#   'ntia',
#   'ombegov',
#   'Open-Sat',
#   'opengovplatform',
#   'ozoneplatform',
#   'peacecorps',
#   'petsc',
#   'presidential-innovation-fellows',
#   'project-open-data',
#   'radiofreeasia',
#   'redhawksdr',
#   'regulationsgov',
#   'sbstusa',
#   'SelectUSA',
#   'SERVIR',
#   'SSAgov',
#   'state-hiu',
#   'sunpy',
#   'us-bea',
#   'US-CBP',
#   'US-Department-of-the-Treasury',
#   'usagov',
#   'usaid',
#   'usajobs',
#   'usasearch',
#   'usbr',
#   'uscensusbureau',
#   'uscis',
#   'usda',
#   'usda-ars-agil',
#   'usda-ars-gbru',
#   'usda-ars-ltar',
#   'usda-ars-nwrc',
#   'usda-ars-wmsru',
#   'USDA-ERS',
#   'USDA-FSA',
#   'USDA-NIFA',
#   'usda-vs',
#   'usdaForestService',
#   'usdepartmentoflabor',
#   'USDeptVeteransAffairs',
#   'usdoj',
#   'usdot-fhwa-stol',
#   'usdot-jpo-ode',
#   'usds',
#   'useda',
#   'usepa',
#   'USFWS',
#   'usg-scope',
#   'USGCRP',
#   'usgpo',
#   'usgs',
#   'USGS-Astrogeology',
#   'usgs-cmg',
#   'usgs-eros',
#   'USGS-OWI',
#   'USGS-R',
#   'USGS-WiM',
#   'usnationalarchives',
#   'usopm',
#   'USPS',
#   'USPTO',
#   'USSBA',
#   'usstatedept',
#   'ustaxcourt',
#   'uswds',
#   'VHAINNOVATIONS',
#   'virtual-world-framework',
#   'visionworkbench',
#   'weather-gov',
#   'WFMRDA',
#   'whitehouse',
#   'XDgov'],
#  'U.S. Local Law Enforcement': ['SanDiegoCountySheriff'],
#  'U.S. Military and Intelligence': ['afseo',
#   'CRREL',
#   'deptofdefense',
#   'dod-cyber-crime-center',
#   'erdc-itl',
#   'iadgov',
#   'info-sharing-environment',
#   'NationalSecurityAgency',
#   'ngageoint',
#   'nsacyber',
#   'project-interoperability',
#   'psns-imf',
#   'shareandprotect',
#   'SIMP',
#   'transcom',
#   'usarmyresearchlab',
#   'USNavalResearchLaboratory'],
#  'U.S. Special District': ['atlregional',
#   'AZMAG',
#   'baaqmd',
#   'cleveland-metroparks',
#   'CMAP-REPOS',
#   'commonwealth-of-puerto-rico',
#   'MAPC',
#   'Metropolitan-Council',
#   'portofsandiego',
#   'psrc'],
#  'U.S. States': ['agrc',
#   'akhealth',
#   'azgs',
#   'cagov',
#   'calsimcallite',
#   'CAWaterBoardDataCenter',
#   'ccap',
#   'coloradodemography',
#   'CTOpenData',
#   'DCGovWeb',
#   'eHawaii',
#   'FGS-FloridaGeologicalSurvey',
#   'gaepdit',
#   'gocodecolorado',
#   'IDAHO-DOC-NCOMS',
#   'idahofishgame',
#   'judicialcouncilcalifornia',
#   'la-ots',
#   'LADCO',
#   'LibraryofVA',
#   'massgov',
#   'MESMD',
#   'MFWP-GIS',
#   'nebraskamap',
#   'nelegislature',
#   'NJOGIS',
#   'njstatelibrary',
#   'ny',
#   'nys-its',
#   'nysenate',
#   'oimt',
#   'okcareertech',
#   'oregonopendata',
#   'ORMetro',
#   'scgeology',
#   'SLNC-DIMP',
#   'State-of-Arizona',
#   'StateOfCalifornia',
#   'swibwi',
#   'tndidd',
#   'TNRIS',
#   'twdb',
#   'TxDOT',
#   'UtahForestryFireStateLands',
#   'VDGIF',
#   'Virginia-Department-of-Health',
#   'Virginia-House-of-Delegates',
#   'vtrans',
#   'vtrans-rail',
#   'WA-Department-of-Agriculture',
#   'wsdot',
#   'WSDOT-GIS'],
#  'U.S. Tribal Nations': ['coquille-indian-tribe', 'osage-nation'],
#  'Ukraine': ['openprocurement'],
#  'United Nations': ['GFDRR',
#   'OCHA-DAP',
#   'UN-ICC',
#   'UN-OCHA',
#   'undp',
#   'unesco',
#   'UNGlobalPlatform',
#   'unicef',
#   'unido',
#   'UNStats',
#   'worldbank',
#   'WorldBank-Transport',
#   'WorldHealthOrganization'],
#  'Venezuela': ['CanaimaGNULinux', 'suscerte']}

# %%
import pandas as pd


all_repos = []
if accounts:
    for country, usernames in accounts.items():
        for username in usernames:
            repo_details = fetch_repository_details(username, github_token)
            if repo_details:
                all_repos.extend(repo_details)
                print(f"Data for {username} fetched and processed.")
            else:
                print(f"Failed to fetch data for {username}")

# Create DataFrame and save to Markdown
if all_repos:
    repos_df = pd.DataFrame(all_repos)
    markdown_file = "all_government_repositories.md"
    save_to_markdown(repos_df, markdown_file)
    print(f"All data saved to {markdown_file}")
    # Optionally save to CSV or another format
    repos_df.to_csv("all_government_repositories.csv", index=False)
    print("Data also saved as a CSV file.")
else:
    print("No repository data collected.")
# Out:
# Data for argob fetched and processed.
# Data for cifasis fetched and processed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 for country, usernames in accounts.items():
#       7     for username in usernames:
# ----> 8         repo_details = fetch_repository_details(username, github_token)
#       9         if repo_details:
#      10             all_repos.extend(repo_details)
#
# Cell In[3], line 35, in fetch_repository_details(username, token)
#      33 if readme_response.status_code == 200:
#      34     readme_data = readme_response.json()
# ---> 35     readme_content = requests.get(readme_data['download_url']).text
#      36     repo_details['readme'] = readme_content[:100]  # Truncate for brevity
#      37 else:
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/Projects/gov_tech_aggregator/.venv/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
repos_df = pd.DataFrame(all_repos)
repos_df
# Out:
#                                 name  \
# 0                  accesibilidad-web
# 1              AR-API-Gateway-Distro
# 2                          AR-Distro
# 3             barra-de-accesibilidad
# 4                              cofra
# 5                     cuidar-android
# 6                         cuidar-ios
# 7          drupal-argentina-borrador
# 8          drupal-argentina-carousel
# 9            drupal-argentina-distro
# 10          drupal-argentina-filtros
# 11          drupal-argentina-helpers
# 12        drupal-argentina-jumbotron
# 13             drupal-argentina-mapa
# 14                            drupar
# 15                      drupar_areas
# 16                        drupar_cck
# 17                drupar_componentes
# 18                     drupar_inicio
# 19                 drupar_multimedia
# 20                   drupar_noticias
# 21                     drupar_poncho
# 22                   drupar_usuarios
# 23                     drupar_vistas
# 24                            elk-bi
# 25                        estandares
# 26                        fontcustom
# 27                   foro-laravel-id
# 28                            Gaucho
# 29                        georef-php
# 30                          afl-fuzz
# 31                        ApproxMVBB
# 32                     basalt-mirror
# 33        basalt-with-persistent-map
# 34                        basalt_ros
# 35                       basalt_ros1
# 36                  bow_vocabularies
# 37                bug-report-scripts
# 38                   caffe-fast-rcnn
# 39                       certificate
# 40                curso-herramientas
# 41                dataset-processing
# 42                       dense-sptam
# 43                 distributed-sptam
# 44  exploiting-gan-internal-capacity
# 45                             FLVIS
# 46                               g2o
# 47                            ghc-cm
# 48       gnss-stereo-inertial-fusion
# 49                           grotloc
# 50                           haddock
# 51                               hmm
# 52                              hogg
# 53                         honggfuzz
# 54                  hs-asn1-encoding
# 55               hs-certificate-x509
# 56                      Juicy.Pixels
# 57                        Kimera-VIO
# 58                    Kimera-VIO-ROS
# 59               language-javascript
#
#                                           description  stars  forks  \
# 0   Repositorio del Equipo de Accesibilidad Web de...     63     17
# 1                                      No description      0      1
# 2                     Distro de Drupal para Gobiernos     12     10
# 3   Plugin que incorpora opciones de accesibilidad...      5      6
# 4                  Sistema de rendición de caja chica      3      5
# 5                                          App Cuidar     75     21
# 6                                          App Cuidar     12      5
# 7   Esta es una distribución de un componente util...      0      1
# 8   Esta es una distribución de un componente util...      0      1
# 9   Esta es una distribución pública del portal de...      0      1
# 10  Esta es una distribución de un componente util...      0      1
# 11  Esta es una distribución de un componente util...      0      1
# 12  Esta es una distribución de un componente util...      0      1
# 13  Esta es una distribución de un componente util...      0      1
# 14  Distribución de Drupal pensada para la creació...      1      3
# 15                                     No description      0      1
# 16                                     No description      0      1
# 17                                     No description      0      1
# 18                                     No description      0      1
# 19                                     No description      0      1
# 20                                     No description      0      1
# 21          Poncho especialmente pensado para drupar.      0      2
# 22                                     No description      0      1
# 23                                     No description      0      1
# 24   Visualizador de datos para la toma de decisiones      6      4
# 25                  Estándares de Servicios Digitales     91     47
# 26  Generate custom icon webfonts from the comfort...      0      0
# 27                                     No description      0      1
# 28             Skin para MediaWiki que utiliza Poncho      0      1
# 29                                     No description      0      1
# 30  Non-official repository for lcamtuf's American...      1      0
# 31  Fast algorithms to compute an approximation of...      0      0
# 32                                     No description      0      0
# 33                                     No description      2      0
# 34                                     No description      1      0
# 35                                     No description      0      0
# 36  Bag of Words vocabularies for appearance-based...      0      0
# 37                                     No description      1      0
# 38                Caffe fork that supports Fast R-CNN      0      0
# 39                                     No description      1      0
# 40  Curso de Herramientas de Machine Learning para...      4      2
# 41   Tools to process the Weed removing robot dataset     14      4
# 42                                       Dense S-PTAM     60     17
# 43                                 Distributed S-PTAM      8      3
# 44  Code for reproducing experiments in "Exploitin...     16      1
# 45                                     No description      1      0
# 46    g2o: A General Framework for Graph Optimization      0      0
# 47                 Prototype GHC with Class Morphisms      4      0
# 48  GNSS-Stereo-Inertial SLAM implementation that ...     27      8
# 49            Ground Truth for Loop Closure (GroTLoC)      1      1
# 50                         Haskell Documentation Tool      1      0
# 51                    hidden markov models in haskell      0      1
# 52  Haskell library and tools to manipulate the Og...      1      2
# 53  A general-purpose, easy-to-use fuzzer with int...      0      0
# 54                                     No description      0      0
# 55                                     No description      0      0
# 56            Haskell library to load & save pictures      1      0
# 57                                     No description      0      0
# 58                                     No description      1      0
# 59                  Parser for JavaScript, in Haskell      0      0
#
#           language                                             readme
# 0   None specified  # Accesibilidad Web\n\n**Repositorio del Equip...
# 1   None specified                            # AR-API-Gateway-Distro
# 2              PHP  # AR-Distro\n\nDistribución Drupal gratuita de...
# 3              PHP  # Barra de "Herramientas de Accesibilidad"\n# ...
# 4              PHP  # Cofra\n\nSistema de rendición de caja chica....
# 5             Java  # Cuidar Android\n\nSe publica aquí el código ...
# 6            Swift  # Cuidar iOS\n\nSe publica aquí el código fuen...
# 7              PHP  # drupal-argentina-borrador\nEsta es una distr...
# 8              PHP  # drupal-argentina-carousel\nEsta es una distr...
# 9              PHP  # drupal-argentina-distro\nEsta es una distrib...
# 10             PHP  # drupal-argentina-filtros\nEsta es una distri...
# 11             PHP  # drupal-argentina-helpers\nEsta es una distri...
# 12             PHP  # drupal-argentina-jumbotron\nEsta es una dist...
# 13             PHP  # drupal-argentina-mapa\nEsta es una distribuc...
# 14        Makefile  # Drupar\nDistribución de Drupal pensada para ...
# 15             PHP                               README not available
# 16             PHP                               README not available
# 17             PHP                               README not available
# 18             PHP                               README not available
# 19             PHP                               README not available
# 20             PHP                               README not available
# 21             CSS                               README not available
# 22             PHP                               README not available
# 23             PHP                               README not available
# 24           Shell  ## Contenido\n\n- [Introducción](#introducción...
# 25            HTML  # Principios y Estándares de Servicios Digital...
# 26            Ruby  [![Gem Version](https://badge.fury.io/rb/fontc...
# 27             PHP  # Foro\n## Pre-requisitos\n* Tener credenciale...
# 28             CSS  # Gaucho\nSkin para [MediaWiki](https://www.me...
# 29             PHP                               README not available
# 30               C                                        docs/README
# 31  None specified  ApproxMVBB \n==========\n\n![C++](https://img....
# 32             C++  [![pipeline status](https://gitlab.com/Vladysl...
# 33             C++  # Basalt for Monado\n\nThis is a fork of [Basa...
# 34           Shell  # Basalt\n\n## Original repository\nThis repos...
# 35             C++  # Basalt VIO ROS wrapper\n\nThis is a ROS wrap...
# 36  None specified  # bow_vocabularies\nBag of Words vocabularies ...
# 37          Python                               README not available
# 38  None specified  # Caffe\n\nCaffe is a deep learning framework ...
# 39         Haskell                               README not available
# 40          Python  Este repositorio contiene los ejercicios y sol...
# 41          Python  *dataset-processing* is a set of scripts to pr...
# 42             C++  # dense-sptam ROS package\nDense S-PTAM is an ...
# 43             C++  DS-PTAM, a distributed architecture for the S-...
# 44          Python  Exploiting GAN Internal Capacity for High-Qual...
# 45             C++  #  FLVIS\n## Feedback Loop Based Visual Inerti...
# 46  None specified  # g2o - General Graph Optimization\n\nLinux: [...
# 47         Haskell  # Class morphisms\n\nPrototype implementation ...
# 48             C++  # GNSS-Stereo-Inertial Fusion\n\nGNSS-SI (GNSS...
# 49          Python  # GroTLoc\n![logo](grotloc_icon.png)\n\n**Grou...
# 50            HTML  # Haddock, a Haskell Documentation Tool [![Bui...
# 51         Haskell  This is a Hidden Markov Model (HMM) library fo...
# 52         Haskell  HOgg - Ogg encapsulation stuffz\n=============...
# 53               C  # honggfuzz #\n\n**Description**\n\n  * A gene...
# 54         Haskell                               README not available
# 55         Haskell                               README not available
# 56         Haskell  ![Juicy logo](https://raw.github.com/Twinside/...
# 57             C++  <div align="center">\n  <a href="http://mit.ed...
# 58             C++  # Kimera-VIO-ROS\n\nROS Wrapper for [Kimera](h...
# 59         Haskell  Parser for JavaScript\n---------------------\n...

# %%
from langchain.prompts import PromptTemplate
from langchain_anthropic import ChatAnthropic
from tqdm import tqdm
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain_core.exceptions import OutputParserException

anthropic_api_key = os.getenv('ANTHROPIC_KEY')
df = repos_df.copy()

def classify_repos(df, topic_list, model_name="claude-3-haiku-20240307"):
    llm = ChatAnthropic(model=model_name, api_key=anthropic_api_key)
    
    summary_prompt = PromptTemplate(
        input_variables=["description", "readme"],
        template="""
        Please provide a summary of the following GitHub repository based on its description and README.md content. If the README.md is not in English, please first translate it to English and then generate a summary. The summary should be concise and in fewer than 5 sentences.
        
        Repository description:
        {description}
        
        README.md content:
        {readme}
        
        Summary:
        """
    )
    
    topic_prompt = PromptTemplate(
        input_variables=["summary", "topic_list"],
        template="""
        Given the following summary of a GitHub repository and a list of potential topics, select the most appropriate topic for the repository. If none of the topics in the list are suitable, generate a new topic label.
        
        Repository summary:
        {summary}
        
        Potential topics:
        {topic_list}
        
        Selected topic:
        """
    )
    
    def generate_summary(row):
        description = row["description"] if pd.notnull(row["description"]) else ""
        readme = row["readme"] if pd.notnull(row["readme"]) else ""
        prompt = summary_prompt.format(description=description, readme=readme)
        summary = llm.invoke(prompt).content
        return summary
    
    response_schemas = [
        ResponseSchema(name="topic", description="The selected topic for the repository.")
    ]
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

    topic_prompt = PromptTemplate(
        input_variables=["summary", "topic_list"],
        template="""
        Given the following summary of a GitHub repository and a list of potential topics, select the most appropriate topic for the repository. If none of the topics in the list are suitable, generate a new topic label.

        Repository summary:
        {summary}

        Potential topics:
        {topic_list}

        Selected topic:
        "{{topic}}"

        PLEASE ONLY RETURN THE TOPIC LABEL AS THE RESPONSE. DO NOT INCLUDE ANY ADDITIONAL TEXT.
        """,
        output_parser=output_parser,
    )

    def classify_repo(readme):
        row = df.loc[df["readme"] == readme].iloc[0]
        summary = generate_summary(row)
        prompt = topic_prompt.format(summary=summary, topic_list=", ".join(topic_list))
        response = llm.invoke(prompt).content

        try:
            topic = output_parser.parse(response)["topic"]
        except OutputParserException:
            # Handle the case when the response is not a valid JSON
            topic = response.strip()  # Extract the topic as a plain string

        if topic not in topic_list:
            topic_list.append(topic)

        return topic
    
    tqdm.pandas(desc="Classifying repositories")
    df["topic"] = df["readme"].progress_apply(classify_repo)
    
    df["summary"] = df.apply(generate_summary, axis=1)
    
    return df, topic_list
# Out:
# Classifying repositories:   0%|          | 0/10 [00:00<?, ?it/s]
# Classifying repositories: 100%|██████████| 10/10 [00:24<00:00,  2.40s/it]
# /var/folders/tg/5ndqpqgn4mvb364_f2l5zxxx9wpnpy/T/ipykernel_10890/3557294341.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["topic"] = df["readme"].progress_apply(classify_repo)
# /var/folders/tg/5ndqpqgn4mvb364_f2l5zxxx9wpnpy/T/ipykernel_10890/3557294341.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["summary"] = df.apply(generate_summary, axis=1)
#                         name  \
# 0          accesibilidad-web
# 1      AR-API-Gateway-Distro
# 2                  AR-Distro
# 3     barra-de-accesibilidad
# 4                      cofra
# 5             cuidar-android
# 6                 cuidar-ios
# 7  drupal-argentina-borrador
# 8  drupal-argentina-carousel
# 9    drupal-argentina-distro
#
#                                          description  stars  forks  \
# 0  Repositorio del Equipo de Accesibilidad Web de...     63     17
# 1                                     No description      0      1
# 2                    Distro de Drupal para Gobiernos     12     10
# 3  Plugin que incorpora opciones de accesibilidad...      5      6
# 4                 Sistema de rendición de caja chica      3      5
# 5                                         App Cuidar     75     21
# 6                                         App Cuidar     12      5
# 7  Esta es una distribución de un componente util...      0      1
# 8  Esta es una distribución de un componente util...      0      1
# 9  Esta es una distribución pública del portal de...      0      1
#
#          language                                             readme  \
# 0  None specified  # Accesibilidad Web\n\n**Repositorio del Equip...
# 1  None specified                            # AR-API-Gateway-Distro
# 2             PHP  # AR-Distro\n\nDistribución Drupal gratuita de...
# 3             PHP  # Barra de "Herramientas de Accesibilidad"\n# ...
# 4             PHP  # Cofra\n\nSistema de rendición de caja chica....
# 5            Java  # Cuidar Android\n\nSe publica aquí el código ...
# 6           Swift  # Cuidar iOS\n\nSe publica aquí el código fuen...
# 7             PHP  # drupal-argentina-borrador\nEsta es una distr...
# 8             PHP  # drupal-argentina-carousel\nEsta es una distr...
# 9             PHP  # drupal-argentina-distro\nEsta es una distrib...
#
#                      topic                                            summary
# 0        web accessibility  The given GitHub repository is maintained by t...
# 1        augmented_reality  The repository "AR-API-Gateway-Distro" does no...
# 2  government_web_platform  Here is a summary of the GitHub repository bas...
# 3        web accessibility  The GitHub repository contains a plugin that a...
# 4    accounting_management  The provided GitHub repository is a system for...
# 5           healthcare_app  Cuidar Android is an open-source project that ...
# 6           healthcare_app  The Cuidar iOS repository contains the source ...
# 7  government_web_platform  The provided GitHub repository is a distributi...
# 8  government_web_platform  Summary:\n\nThis repository contains a compone...
# 9  government_web_platform  Summary:\n\nThis GitHub repository contains a ...

# %%
df, topic_list = classify_repos(repos_df, topic_list=['ai', 'web development', 'data science', 'cybersecurity'])
df
df.to_csv('all_gov_projects.csv', index=False)

# %%
import requests
import yaml
import os
from dotenv import load_dotenv

def fetch_gov_github_accounts(url):
    response = requests.get(url)
    if response.status_code == 200:
        return yaml.safe_load(response.text)
    else:
        return None

def fetch_repository_details(username, token):
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    repos_response = requests.get(repos_url, headers=headers)
    
    if repos_response.status_code == 200:
        repos_data = repos_response.json()
        full_repo_details = []
        
        for repo in repos_data:
            repo_details = {
                'name': repo['name'],
                'description': repo['description'] or "No description",
                'stars': repo['stargazers_count'],
                'language': repo['language'] or "None specified"
            }
            # Fetch the README file
            readme_url = f"https://api.github.com/repos/{username}/{repo['name']}/readme"
            readme_response = requests.get(readme_url, headers=headers)
            if readme_response.status_code == 200:
                readme_data = readme_response.json()
                readme_content = requests.get(readme_data['download_url']).text
                repo_details['readme'] = readme_content[:100]  # Truncate for brevity
            else:
                repo_details['readme'] = "README not available"
            
            full_repo_details.append(repo_details)
        
        return full_repo_details
    else:
        return None

def save_to_markdown(repos, filename):
    with open(filename, 'w') as f:
        f.write('| Repository Name | Description | Stars | Language | README |\n')
        f.write('|-----------------|-------------|-------|----------|--------|\n')
        for repo in repos:
            f.write(f"| {repo['name']} | {repo['description']} | {repo['stars']} | {repo['language']} | {repo['readme'][:50]}... |\n")


# Load environment variables from .env file
load_dotenv('.env')

# Access environment variables
github_token = os.getenv('GITHUB_TOKEN')


# Main execution
url = "https://raw.githubusercontent.com/github/government.github.com/gh-pages/_data/governments.yml"
accounts = fetch_gov_github_accounts(url)

accounts
# Out:
# {'Argentina': ['argob',
#   'cifasis',
#   'gcba',
#   'inti-cmnb',
#   'municipalidad-de-vicente-lopez',
#   'municipioriogrande'],
#  'Australia': ['actesa',
#   'actgov',
#   'agnsw',
#   'AtlasOfLivingAustralia',
#   'ausdto',
#   'australianantarcticdatacentre',
#   'AustralianAntarcticDivision',
#   'berowrarfb',
#   'bom-radar',
#   'city-of-melbourne',
#   'commerce-wa-ols',
#   'consumerdataright',
#   'data61',
#   'datagovau',
#   'dbca-wa',
#   'dpc-sdp',
#   'dpipwe',
#   'dssgovaus',
#   'envris',
#   'Fire-and-Rescue-NSW',
#   'gccgisteam',
#   'GeoscienceAustralia',
#   'govau',
#   'govcms',
#   'gs-dawr',
#   'healthgovau',
#   'Healthway',
#   'hiscom',
#   'innovationgovau',
#   'IPAustralia',
#   'Landgate',
#   'nla',
#   'NSW-eTendering',
#   'NSWPlanning',
#   'pmcau',
#   'PublicRecordOfficeVictoria',
#   'qld-gov-au',
#   'srnsw',
#   'SunshineCoastCouncil',
#   'treasury-aus',
#   'victoriangovernment',
#   'wagov',
#   'wamuseum'],
#  'Austria': ['datagvat'],
#  'Belgium': ['belgianpolice',
#   'CIRB',
#   'Fedict',
#   'inbo',
#   'NationalBankBelgium',
#   'onroerenderfgoed',
#   'StadGent'],
#  'Bolivia': ['adsib', 'geobolivia'],
#  'Brazil': ['bacendeinf',
#   'camaradosdeputadosoficial',
#   'cenima-ibama',
#   'cislgov',
#   'culturagovbr',
#   'dadosgovbr',
#   'dataprev',
#   'EscolaDeSaudePublica',
#   'fablablivresp',
#   'fateczonaleste',
#   'gabinetedigital',
#   'govbr',
#   'GovBrasil',
#   'imagov',
#   'InstitutoBenjaminConstant',
#   'interlegis',
#   'justicagovbr',
#   'labhackercd',
#   'lexml',
#   'MP-ES',
#   'MP-RJ',
#   'pensandoodireito',
#   'plonegovbr',
#   'pr-snas',
#   'prefeitura-rio',
#   'prefeiturasp',
#   'PROCERGS',
#   'prodest',
#   'secom-tocantins',
#   'secultce',
#   'sepinf-inc',
#   'servicosgovbr',
#   'tcers',
#   'tisorocaba',
#   'tre-pa',
#   'wpgovbr'],
#  'Bulgaria': ['govbg', 'governmentbg'],
#  'Cambodia': ['e-Government-Cambodia'],
#  'Canada': ['AAFC-MBB',
#   'abgov',
#   'asc-csa',
#   'bac-lac',
#   'BCGov',
#   'canada-ca',
#   'cds-snc',
#   'CityofEdmonton',
#   'cityofgreatersudbury',
#   'cityofottawa',
#   'CityOfSarnia',
#   'cityofsurrey',
#   'CityofToronto',
#   'cityssm',
#   'cngo',
#   'CommunicationSecurityEstablishment',
#   'csbp-cpse',
#   'CSPS-EFPC-DAAN',
#   'CybercentreCanada',
#   'ECCC-MSC',
#   'eodms-sgdot',
#   'esdc-devx',
#   'esdc-edsc',
#   'ExchangeBC',
#   'fgpv-vpgf',
#   'gc-proto',
#   'GCTC-NTGC',
#   'gctools-outilsgc',
#   'GeoCanViz',
#   'GNWT',
#   'GovAlta',
#   'infra-geo-ouverte',
#   'justicecanada',
#   'LMID-DIMT',
#   'MC-MBO-WebPublishingTeam',
#   'MetPX',
#   'MTS-STM',
#   'nrc-cnrc',
#   'NRCan',
#   'nsgov',
#   'ongov',
#   'open-data',
#   'phac-aspc',
#   'phac-nml',
#   'PHACDataHub',
#   'pspc-spac',
#   'PSPC-SPAC-buyandsell',
#   'RAMP-PCAR',
#   'RDOQ',
#   'ServiceCanada',
#   'StatCan',
#   'TBS-EACPD',
#   'tc-ca',
#   'veteransaffairscanada',
#   'VilledeMontreal',
#   'wet-boew'],
#  'Chile': ['e-gob'],
#  'Colombia': ['AltaConsejeriaTIC', 'evaluon', 'idu-bogota'],
#  'Czech Republic': ['MinistryOfJusticeCZ', 'NLCR', 'opendata-mvcr'],
#  'Denmark': ['kb-dk',
#   'Kortforsyningen',
#   'NationalMuseumofDenmark',
#   'Notalib',
#   'skat',
#   'ssi-dk',
#   'StatensMuseumforKunst'],
#  'Ecuador': ['inamhi', 'innovacionsnap', 'senescyt'],
#  'Egypt': ['informationtechnologyinstitute'],
#  'Estonia': ['e-gov', 'kinnisvara', 'MKM-ITAO', 'open-eid', 'opendata-ee'],
#  'Ethiopia': ['ethiopian'],
#  'European Union': ['digital-services-act',
#   'ec-europa',
#   'eea',
#   'eu-digital-green-certificates',
#   'eu-digital-identity-wallet',
#   'europarl',
#   'european-central-bank',
#   'europeana',
#   'openeuropa'],
#  'Finland': ['6Aika',
#   'City-of-Helsinki',
#   'City-of-Turku',
#   'CSC-IT-Center-for-Science',
#   'espoon-voltti',
#   'finnishtransportagency',
#   'Helsingin-kaupungin-tietokeskus',
#   'helsinki-city-library',
#   'HSLdevcom',
#   'Lounaispaikka',
#   'lukefi',
#   'NatLibFi',
#   'nlsfi',
#   'opetushallitus',
#   'sykefi',
#   'vrk-kpa'],
#  'France': ['afimb',
#   'AlsaceDigitale',
#   'AmbaNum',
#   'ansforge',
#   'ANSSI-FR',
#   'ApieFrance',
#   'atih',
#   'betagouv',
#   'BRGM',
#   'cea-hpc',
#   'cea-leti',
#   'cea-list',
#   'cea-sec',
#   'clipos',
#   'clipos-archive',
#   'communaute-cimi',
#   'culturecommunication',
#   'cw-leia',
#   'DGFiP',
#   'diplomatiegouvfr',
#   'disic',
#   'DREAL-NA',
#   'entrepreneur-interet-general',
#   'erasme',
#   'etalab',
#   'Inist-CNRS',
#   'InseeFr',
#   'lutece-secteur-public',
#   'MINAGRI-INITIAL',
#   'MinistereSupRecherche',
#   'MTES-MCT',
#   'nanterre',
#   'nantesmetropole',
#   'opencti-platform',
#   'PnCevennes',
#   'PnEcrins',
#   'PnX-SI',
#   'polewebmaedi',
#   'ProgrammeVitam',
#   'region-bretagne',
#   'sgmap-agd',
#   'SocialGouv',
#   'SocieteNumerique',
#   'strasbourg',
#   'wookey-project'],
#  'French Polynesia': ['sipf'],
#  'Germany': ['Basisvisualisierung',
#   'BSI-Bund',
#   'buehl',
#   'CERT-Bund',
#   'corona-warn-app',
#   'dbmdz',
#   'Digitaler-Impfnachweis',
#   'digitalservicebund',
#   'gbv',
#   'GovDataOfficial',
#   'hbz',
#   'isyfact',
#   'it-at-m',
#   'kdn-nrw',
#   'kreis-viersen',
#   'lobid',
#   'OpenBfS',
#   'OpenNRW',
#   'regional-digital',
#   'robert-koch-institut',
#   'rostock',
#   'stadt-bielefeld',
#   'stadt-karlsruhe',
#   'StadtBruchsal',
#   'stadtulm'],
#  'Guatemala': ['minfingt'],
#  'Hong Kong': ['datagovhk'],
#  'Hungary': ['fphgov'],
#  'India': ['DataPortalIndia', 'ISRO', 'itschool', 'npci'],
#  'Indonesia': ['bolsel', 'jabardigitalservice', 'pemkab-rembang'],
#  'International': ['EL-BID', 'IATI', 'ogpl'],
#  'Ireland': ['HSEIreland'],
#  'Isle of Man': ['Isle-Of-Man-Government'],
#  'Israel': ['CIOIL', 'Digital-Israel', 'MohGovIL', 'MostIL'],
#  'Italy': ['AgID',
#   'ComuneBologna',
#   'Formez',
#   'pcm-dpc',
#   'PloneGov-IT',
#   'RegioneER',
#   'TeamDigitale'],
#  'Japan': ['city-of-kobe',
#   'codefornamie',
#   'gsi-cyberjapan',
#   'nhohq',
#   'nims-dpfc',
#   'wakayama-pref-org'],
#  'Jersey': ['statesofjersey'],
#  'Kosovo': ['map-ashi'],
#  'Latvia': ['CSBLatvia'],
#  'Lithuania': ['AplinkosMinisterija',
#   'govlt',
#   'ivpk',
#   'viesujupirkimutarnyba',
#   'vilnius'],
#  'Luxemburg': ['circl', 'Geoportail-Luxembourg', 'natliblux', 'opendatalu'],
#  'Malaysia': ['pmo2'],
#  'Mauritius': ['MUnosecc'],
#  'Mexico': ['CSB-IG',
#   'DDT-INMEGEN',
#   'inmegen',
#   'LabLeon',
#   'mxabierto',
#   'PJECZ',
#   'profeco',
#   'redoaxacadetodos'],
#  'Netherlands': ['Amsterdam',
#   'dataoverheid',
#   'GemeenteAlmelo',
#   'GemeenteEde',
#   'gemeentemuseum',
#   'Geonovum',
#   'Haarlem',
#   'IenS-Velsen',
#   'KBNLresearch',
#   'Logius-standaarden',
#   'MinBZK',
#   'MinELenI',
#   'minvws',
#   'Pleio',
#   'provinciegroningen',
#   'provincieNH',
#   'StichtingHergebruikOverheid',
#   'TweedeKamer',
#   'zaanstad'],
#  'New Zealand': ['CanterburyRegionalCouncil',
#   'data-govt-nz',
#   'DigitalNZ',
#   'docgovtnz',
#   'ElectricityAuthority',
#   'GOVTNZ',
#   'linz',
#   'localgovernment',
#   'MfE-NZ',
#   'nz-social-investment-agency',
#   'opcnz',
#   'te-papa'],
#  'Norway': ['altinn',
#   'bergenkommune',
#   'brreg',
#   'difi',
#   'digibib',
#   'DirektoratetForByggkvalitet',
#   'dsb-norge',
#   'dss-web',
#   'kartverket',
#   'knreise',
#   'KRD-KOMM-VL',
#   'metno',
#   'miljodir',
#   'nasjonalmuseet',
#   'navikt',
#   'nlbdev',
#   'Nordland-fylkeskommune',
#   'politiet',
#   'Riksrevisjonen',
#   'Rogaland',
#   'rutebanken',
#   'ruterno',
#   'Skatteetaten',
#   'StatensPensjonskasse',
#   'statisticsnorway',
#   'telemark',
#   'telemark-arkiv',
#   'Tolletaten',
#   'uninett',
#   'vegvesen'],
#  'Panama': ['IFARHU', 'miambiente'],
#  'Paraguay': ['mecpy', 'SENATICS'],
#  'Peru': ['imarpe'],
#  'Philippines': ['corcueraromblon', 'govph', 'igovphil', 'Laoag-City'],
#  'Poland': ['coi-gov-pl', 'Ministerstwo-Cyfryzacji', 'nationalmuseum'],
#  'Portugal': ['amagovpt'],
#  'Republic of Korea': ['molit-korea'],
#  'Romania': ['govro', 'MinistryOfLabor'],
#  'Russia': ['cikrf', 'ghalghai', 'kznru', 'moscow-technologies'],
#  'Saudi Arabia': ['SAS-NCDC'],
#  'Singapore': ['dsaidgovsg', 'govtechsg', 'moexmen', 'opengovsg'],
#  'Slovakia': ['slovak-egov'],
#  'South Africa': ['eddZA'],
#  'Spain': ['AjMalgrat',
#   'AjuntamentdeBarcelona',
#   'AjuntamentdeCalafell',
#   'AjuntamentdeCastello',
#   'AjuntamentDeGava',
#   'AjuntamentDeMataro',
#   'AjuntamentdeReus',
#   'AjuntamentdeSabadell',
#   'AjuntamentdeSantCugat',
#   'AjuntamentdeTerrassa',
#   'AyuntamientoMadrid',
#   'ctt-gob-es',
#   'ErabakiPamplona',
#   'gencat',
#   'GobiernoLaRioja',
#   'HospitaletDeLlobregat',
#   'icane',
#   'lliurex',
#   'projectestac',
#   'vilanovailageltru'],
#  'Sweden': ['Alingsas-Kommun',
#   'arbetsformedlingen',
#   'domstol',
#   'dotse',
#   'elegnamnden',
#   'Forsakringskassan',
#   'gbif-sweden',
#   'Helsingborg',
#   'helsingborg-stad',
#   'ISOF-ITD',
#   'jobtechswe',
#   'kungbib',
#   'Lantmateriet',
#   'libris',
#   'lldd',
#   'lshSWE',
#   'malmostad',
#   'mtmse',
#   'NationalmuseumSWE',
#   'NordicMuseum',
#   'regionhalland',
#   'regionostergotland',
#   'riksantikvarieambetet',
#   'riksarkivet',
#   'rinfo',
#   'sambruk',
#   'SciLifeLab',
#   'SICS',
#   'skolverket',
#   'smhi',
#   'SodertornHB',
#   'statens-maritima-museer',
#   'Statenspersonadressregister',
#   'statisticssweden',
#   'Sundsvallskommun',
#   'Sunet',
#   'sverigesradio',
#   'SVT',
#   'SwedenConnect',
#   'swedish-council-for-higher-education',
#   'swedishpensionsagency',
#   'The-Municipality-of-Staffanstorp',
#   'umea-kommun',
#   'Vastra-Gotalandsregionen',
#   'vasttrafik'],
#  'Switzerland': ['admin-ch',
#   'alv-ch',
#   'BFS-SHS-MSAS',
#   'dsi-vd',
#   'FNSKtZH',
#   'geoadmin',
#   'gisktzh',
#   'kanton-aargau',
#   'kanton-bern',
#   'metas-ch',
#   'ogdch',
#   'ogdtg',
#   'opendatabs',
#   'opendatazurich',
#   'openZH',
#   'SFOE',
#   'sitn',
#   'statistikstadtzuerich',
#   'statistikZH',
#   'VerkehrsbetriebeZuerich'],
#  'Taiwan': ['moda-gov-tw', 'pdis', 'taipeicity'],
#  'Thailand': ['DGA-Thailand'],
#  'U.K. Central': ['111online',
#   'alphagov',
#   'BEACmodel',
#   'britishlibrary',
#   'cabinetoffice',
#   'CDPS-Wales',
#   'CJSCommonPlatform',
#   'co-cddo',
#   'communitiesuk',
#   'companieshouse',
#   'CPS-Innovation',
#   'datagovuk',
#   'datasciencecampus',
#   'decc',
#   'defra',
#   'DFE-Digital',
#   'dfid',
#   'digital-preservation',
#   'directgov-innovate',
#   'dstl',
#   'dvla',
#   'dvsa',
#   'dwp',
#   'GCHQ',
#   'gds-dead',
#   'gds-operations',
#   'govuk-one-login',
#   'guidance-guarantee-programme',
#   'hmcts',
#   'HMPO',
#   'hmrc',
#   'HO-CTO',
#   'houseofcommonslibrary',
#   'informatics-lab',
#   'insolvencyservice',
#   'intellectual-property-office',
#   'IQuOD',
#   'jncc',
#   'JNCC-UK',
#   'jules-lsm',
#   'LandRegistry',
#   'landregistry-ops',
#   'lgss',
#   'LocalGovDigital',
#   'MarineScotlandScience',
#   'MetOffice',
#   'MetOfficeSpaceApps',
#   'metomi',
#   'MHRA',
#   'ministryofjustice',
#   'moj-analytical-services',
#   'naouk',
#   'nationalarchives',
#   'NationalCrimeAgency',
#   'NationalLibraryOfScotland',
#   'nhsconnect',
#   'nhsdigital',
#   'nhsengland',
#   'nhsuk',
#   'NHSX',
#   'nice-digital',
#   'nihp-public',
#   'OfqualGovUK',
#   'ONSdigital',
#   'openregister',
#   'osgeouk',
#   'scottishgovernment',
#   'SkillsFundingAgency',
#   'tanc-ahrc',
#   'ukforeignoffice',
#   'ukgovdatascience',
#   'UKGovernmentBEIS',
#   'UKHomeOffice',
#   'UKHomeOfficeForms',
#   'UKLocation',
#   'ukncsc',
#   'uktrade',
#   'ukwa'],
#  'U.K. Councils': ['BathnesDevelopment',
#   'BracknellForestCouncil',
#   'brighton-hove-gov-uk',
#   'BristolCityCouncil',
#   'CamdenCouncil',
#   'cityofyork',
#   'devoncc',
#   'DevonCountyCouncil',
#   'Dorset-Council-UK',
#   'DundeeCityCouncil',
#   'east-sussex-county-council',
#   'edinburghcouncil',
#   'essexcountycouncil',
#   'gmfrs',
#   'GuildfordBC',
#   'HfdsCouncil',
#   'kentcc',
#   'LambethCouncil',
#   'lichfield-district-council',
#   'LondonBoroughSutton',
#   'LutonCouncil',
#   'openglasgow',
#   'RotherDC',
#   'RoyalBoroughKingston',
#   'smbc-digital',
#   'surreydigitalservices',
#   'thehighlandcouncil',
#   'TraffordCouncil',
#   'warwickshire',
#   'wealden',
#   'west-berkshire-council',
#   'wmfs'],
#  'U.S. City': ['austincodeit',
#   'Baltimore-City-EGIS',
#   'berkeleypubliclibrary',
#   'BostonRedevelop',
#   'cambridgedata',
#   'cambridgegis',
#   'chicago',
#   'city-of-bellingham',
#   'city-of-bloomington',
#   'cityofasheville',
#   'CityOfAuburnAL',
#   'cityofaustin',
#   'cityofboise',
#   'CityOfBoston',
#   'cityofboulder',
#   'cityofburlington',
#   'cityofchattanooga',
#   'CityOfDetroit',
#   'CityOfLosAngeles',
#   'cityofnewyork',
#   'CityOfPhiladelphia',
#   'CityofPittsburgh',
#   'cityofportland',
#   'CityofReno',
#   'CityofSanFrancisco',
#   'CityofSantaMonica',
#   'cityofsomerville',
#   'cityofvernonia',
#   'CityOfVirginiaBeach',
#   'cityofwestsacramento',
#   'CityofYakima',
#   'cno-opa',
#   'CORaleigh',
#   'CUMTD',
#   'DCCouncil',
#   'DCgov',
#   'DenverDev',
#   'digitalinclusion',
#   'egovpdx',
#   'Honolulu',
#   'kcmo',
#   'lfucg',
#   'longbeachinnovationteam',
#   'LouisvilleMetro',
#   'louisvillemetro-innovation',
#   'mnhrc',
#   'mnylc',
#   'moda-nyc',
#   'monum',
#   'NewYorkCityCouncil',
#   'NYCComptroller',
#   'nycdot',
#   'NYCPlanning',
#   'onc-healthit',
#   'OpenGovDC',
#   'p2g',
#   'pdxgis',
#   'PierceCountyWA',
#   'ProBonoDC',
#   'ridertd',
#   'SantaClarita',
#   'sfbart',
#   'SiloamSprings',
#   'southbendin',
#   'TownOfBrookline',
#   'tucsonaz'],
#  'U.S. County': ['anoka-script-team',
#   'ArlingtonCounty',
#   'baltimorecounty',
#   'BayAreaMetro',
#   'bouldercounty',
#   'CanyonCounty',
#   'CarverCounty',
#   'donaanacounty',
#   'fairfieldcountyit',
#   'fpdcc',
#   'HarrisCountyFOA',
#   'HennepinCountyPublicDefender',
#   'LACMTA',
#   'MCLD',
#   'pottcountyit',
#   'saccounty',
#   'sfcta',
#   'slugis'],
#  'U.S. Federal': ['18f',
#   'adl-aicc',
#   'adlnet',
#   'afrl',
#   'arcticlcc',
#   'BBGInnovate',
#   'bfelob',
#   'blue-button',
#   'businessusa',
#   'CA-CST-Library',
#   'CA-CST-SII',
#   'ccmc',
#   'CDCgov',
#   'cfpb',
#   'cigiegov',
#   'cisagov',
#   'cloud-gov',
#   'cmsgov',
#   'commercedataservice',
#   'commercegov',
#   'demand-driven-open-data',
#   'department-of-veterans-affairs',
#   'didsr',
#   'digital-analytics-program',
#   'dodcio',
#   'doecode',
#   'doi-open-data',
#   'EEOC',
#   'energyapps',
#   'erdc',
#   'eregs',
#   'FAA-Aviation-Data-Portal',
#   'fcc',
#   'fda',
#   'fecgov',
#   'Federal-Aviation-Administration',
#   'federal-courts-software-factory',
#   'federaltradecommission',
#   'fedspendingtransparency',
#   'firelab',
#   'globegit',
#   'gopleader',
#   'government-services',
#   'GrainGenes',
#   'gsa',
#   'gsa-oes',
#   'hhs',
#   'HHS-AHRQ',
#   'HHSDigitalMediaAPIPlatform',
#   'HHSIDEAlab',
#   'historyatstate',
#   'IIP-Design',
#   'IMDProjects',
#   'imls',
#   'informaticslab',
#   'Innovation-Toolkit',
#   'internationaltradeadministration',
#   'ioos',
#   'IRSgov',
#   'keplergo',
#   'libraryofcongress',
#   'M-O-S-E-S',
#   'mcc-gov',
#   'missioncommand',
#   'nasa',
#   'nasa-develop',
#   'nasa-gibs',
#   'NASA-rdt',
#   'nasa-tournament-lab',
#   'nasaworldwind',
#   'NationalGuard',
#   'nationalparkservice',
#   'navadmc',
#   'NCRN',
#   'NeoGeographyToolkit',
#   'nesii',
#   'ngds',
#   'nhanes',
#   'nidcd',
#   'NIEM',
#   'NMB-Dev',
#   'NMML',
#   'NOAA-EPIC',
#   'noaa-gfdl',
#   'NOAA-ORR-ERD',
#   'noaa-pmel',
#   'ntia',
#   'ombegov',
#   'Open-Sat',
#   'opengovplatform',
#   'ozoneplatform',
#   'peacecorps',
#   'petsc',
#   'presidential-innovation-fellows',
#   'project-open-data',
#   'radiofreeasia',
#   'redhawksdr',
#   'regulationsgov',
#   'sbstusa',
#   'SelectUSA',
#   'SERVIR',
#   'SSAgov',
#   'state-hiu',
#   'sunpy',
#   'us-bea',
#   'US-CBP',
#   'US-Department-of-the-Treasury',
#   'usagov',
#   'usaid',
#   'usajobs',
#   'usasearch',
#   'usbr',
#   'uscensusbureau',
#   'uscis',
#   'usda',
#   'usda-ars-agil',
#   'usda-ars-gbru',
#   'usda-ars-ltar',
#   'usda-ars-nwrc',
#   'usda-ars-wmsru',
#   'USDA-ERS',
#   'USDA-FSA',
#   'USDA-NIFA',
#   'usda-vs',
#   'usdaForestService',
#   'usdepartmentoflabor',
#   'USDeptVeteransAffairs',
#   'usdoj',
#   'usdot-fhwa-stol',
#   'usdot-jpo-ode',
#   'usds',
#   'useda',
#   'usepa',
#   'USFWS',
#   'usg-scope',
#   'USGCRP',
#   'usgpo',
#   'usgs',
#   'USGS-Astrogeology',
#   'usgs-cmg',
#   'usgs-eros',
#   'USGS-OWI',
#   'USGS-R',
#   'USGS-WiM',
#   'usnationalarchives',
#   'usopm',
#   'USPS',
#   'USPTO',
#   'USSBA',
#   'usstatedept',
#   'ustaxcourt',
#   'uswds',
#   'VHAINNOVATIONS',
#   'virtual-world-framework',
#   'visionworkbench',
#   'weather-gov',
#   'WFMRDA',
#   'whitehouse',
#   'XDgov'],
#  'U.S. Local Law Enforcement': ['SanDiegoCountySheriff'],
#  'U.S. Military and Intelligence': ['afseo',
#   'CRREL',
#   'deptofdefense',
#   'dod-cyber-crime-center',
#   'erdc-itl',
#   'iadgov',
#   'info-sharing-environment',
#   'NationalSecurityAgency',
#   'ngageoint',
#   'nsacyber',
#   'project-interoperability',
#   'psns-imf',
#   'shareandprotect',
#   'SIMP',
#   'transcom',
#   'usarmyresearchlab',
#   'USNavalResearchLaboratory'],
#  'U.S. Special District': ['atlregional',
#   'AZMAG',
#   'baaqmd',
#   'cleveland-metroparks',
#   'CMAP-REPOS',
#   'commonwealth-of-puerto-rico',
#   'MAPC',
#   'Metropolitan-Council',
#   'portofsandiego',
#   'psrc'],
#  'U.S. States': ['agrc',
#   'akhealth',
#   'azgs',
#   'cagov',
#   'calsimcallite',
#   'CAWaterBoardDataCenter',
#   'ccap',
#   'coloradodemography',
#   'CTOpenData',
#   'DCGovWeb',
#   'eHawaii',
#   'FGS-FloridaGeologicalSurvey',
#   'gaepdit',
#   'gocodecolorado',
#   'IDAHO-DOC-NCOMS',
#   'idahofishgame',
#   'judicialcouncilcalifornia',
#   'la-ots',
#   'LADCO',
#   'LibraryofVA',
#   'massgov',
#   'MESMD',
#   'MFWP-GIS',
#   'nebraskamap',
#   'nelegislature',
#   'NJOGIS',
#   'njstatelibrary',
#   'ny',
#   'nys-its',
#   'nysenate',
#   'oimt',
#   'okcareertech',
#   'oregonopendata',
#   'ORMetro',
#   'scgeology',
#   'SLNC-DIMP',
#   'State-of-Arizona',
#   'StateOfCalifornia',
#   'swibwi',
#   'tndidd',
#   'TNRIS',
#   'twdb',
#   'TxDOT',
#   'UtahForestryFireStateLands',
#   'VDGIF',
#   'Virginia-Department-of-Health',
#   'Virginia-House-of-Delegates',
#   'vtrans',
#   'vtrans-rail',
#   'WA-Department-of-Agriculture',
#   'wsdot',
#   'WSDOT-GIS'],
#  'U.S. Tribal Nations': ['coquille-indian-tribe', 'osage-nation'],
#  'Ukraine': ['openprocurement'],
#  'United Nations': ['GFDRR',
#   'OCHA-DAP',
#   'UN-ICC',
#   'UN-OCHA',
#   'undp',
#   'unesco',
#   'UNGlobalPlatform',
#   'unicef',
#   'unido',
#   'UNStats',
#   'worldbank',
#   'WorldBank-Transport',
#   'WorldHealthOrganization'],
#  'Venezuela': ['CanaimaGNULinux', 'suscerte']}

# %%
import pandas as pd

all_repos = []
if accounts:
    for country, usernames in accounts.items():
        for username in usernames:
            repo_details = fetch_repository_details(username, github_token)
            if repo_details:
                all_repos.extend(repo_details)
                print(f"Data for {username} fetched and processed.")
            else:
                print(f"Failed to fetch data for {username}")

# Create DataFrame and save to Markdown
if all_repos:
    repos_df = pd.DataFrame(all_repos)
    markdown_file = "all_government_repositories.md"
    save_to_markdown(repos_df, markdown_file)
    print(f"All data saved to {markdown_file}")
    # Optionally save to CSV or another format
    repos_df.to_csv("all_government_repositories.csv", index=False)
    print("Data also saved as a CSV file.")
else:
    print("No repository data collected.")
# Out:
# Data for argob fetched and processed.
# Data for cifasis fetched and processed.
# Data for gcba fetched and processed.
# Data for inti-cmnb fetched and processed.
# Data for municipalidad-de-vicente-lopez fetched and processed.
# Data for municipioriogrande fetched and processed.
# Failed to fetch data for actesa
# Data for actgov fetched and processed.
# Data for agnsw fetched and processed.
# Data for AtlasOfLivingAustralia fetched and processed.
# Data for ausdto fetched and processed.
# Data for australianantarcticdatacentre fetched and processed.
# Data for AustralianAntarcticDivision fetched and processed.
# Data for berowrarfb fetched and processed.
# Data for bom-radar fetched and processed.
# Data for city-of-melbourne fetched and processed.
# Data for commerce-wa-ols fetched and processed.
# Data for consumerdataright fetched and processed.
# Data for data61 fetched and processed.
# Data for datagovau fetched and processed.
# Data for dbca-wa fetched and processed.
# Data for dpc-sdp fetched and processed.
# Data for dpipwe fetched and processed.
# Data for dssgovaus fetched and processed.
# Data for envris fetched and processed.
# Failed to fetch data for Fire-and-Rescue-NSW
# Data for gccgisteam fetched and processed.
# Data for GeoscienceAustralia fetched and processed.
# Data for govau fetched and processed.
# Data for govcms fetched and processed.
# Data for gs-dawr fetched and processed.
# Data for healthgovau fetched and processed.
# Failed to fetch data for Healthway
# Data for hiscom fetched and processed.
# Data for innovationgovau fetched and processed.
# Data for IPAustralia fetched and processed.
# Data for Landgate fetched and processed.
# Data for nla fetched and processed.
# Data for NSW-eTendering fetched and processed.
# Data for NSWPlanning fetched and processed.
# Data for pmcau fetched and processed.
# Data for PublicRecordOfficeVictoria fetched and processed.
# Data for qld-gov-au fetched and processed.
# Data for srnsw fetched and processed.
# Data for SunshineCoastCouncil fetched and processed.
# Failed to fetch data for treasury-aus
# Data for victoriangovernment fetched and processed.
# Data for wagov fetched and processed.
# Data for wamuseum fetched and processed.
# Data for datagvat fetched and processed.
# Data for belgianpolice fetched and processed.
# Data for CIRB fetched and processed.
# Data for Fedict fetched and processed.
# Data for inbo fetched and processed.
# Data for NationalBankBelgium fetched and processed.
# Data for onroerenderfgoed fetched and processed.
# Data for StadGent fetched and processed.
# Data for adsib fetched and processed.
# Data for geobolivia fetched and processed.
# Data for bacendeinf fetched and processed.
# Failed to fetch data for camaradosdeputadosoficial
# Data for cenima-ibama fetched and processed.
# Data for cislgov fetched and processed.
# Data for culturagovbr fetched and processed.
# Data for dadosgovbr fetched and processed.
# Data for dataprev fetched and processed.
# Failed to fetch data for EscolaDeSaudePublica
# Data for fablablivresp fetched and processed.
# Data for fateczonaleste fetched and processed.
# Data for gabinetedigital fetched and processed.
# Data for govbr fetched and processed.
# Data for GovBrasil fetched and processed.
# Data for imagov fetched and processed.
# Data for InstitutoBenjaminConstant fetched and processed.
# Data for interlegis fetched and processed.
# Data for justicagovbr fetched and processed.
# Data for labhackercd fetched and processed.
# Data for lexml fetched and processed.
# Data for MP-ES fetched and processed.
# Data for MP-RJ fetched and processed.
# Data for pensandoodireito fetched and processed.
# Data for plonegovbr fetched and processed.
# Data for pr-snas fetched and processed.
# Data for prefeitura-rio fetched and processed.
# Data for prefeiturasp fetched and processed.
# Data for PROCERGS fetched and processed.
# Data for prodest fetched and processed.
# Data for secom-tocantins fetched and processed.
# Data for secultce fetched and processed.
# Data for sepinf-inc fetched and processed.
# Data for servicosgovbr fetched and processed.
# Failed to fetch data for tcers
# Data for tisorocaba fetched and processed.
# Data for tre-pa fetched and processed.
# Data for wpgovbr fetched and processed.
# Data for govbg fetched and processed.
# Data for governmentbg fetched and processed.
# Data for e-Government-Cambodia fetched and processed.
# Failed to fetch data for AAFC-MBB
# Data for abgov fetched and processed.
# Data for asc-csa fetched and processed.
# Data for bac-lac fetched and processed.
# Data for BCGov fetched and processed.
# Data for canada-ca fetched and processed.
# Data for cds-snc fetched and processed.
# Data for CityofEdmonton fetched and processed.
# Data for cityofgreatersudbury fetched and processed.
# Data for cityofottawa fetched and processed.
# Data for CityOfSarnia fetched and processed.
# Data for cityofsurrey fetched and processed.
# Data for CityofToronto fetched and processed.
# Data for cityssm fetched and processed.
# Data for cngo fetched and processed.
# Failed to fetch data for CommunicationSecurityEstablishment
# Data for csbp-cpse fetched and processed.
# Data for CSPS-EFPC-DAAN fetched and processed.
# Data for CybercentreCanada fetched and processed.
# Data for ECCC-MSC fetched and processed.
# Data for eodms-sgdot fetched and processed.
# Data for esdc-devx fetched and processed.
# Data for esdc-edsc fetched and processed.
# Data for ExchangeBC fetched and processed.
# Data for fgpv-vpgf fetched and processed.
# Data for gc-proto fetched and processed.
# Data for GCTC-NTGC fetched and processed.
# Data for gctools-outilsgc fetched and processed.
# Data for GeoCanViz fetched and processed.
# Data for GNWT fetched and processed.
